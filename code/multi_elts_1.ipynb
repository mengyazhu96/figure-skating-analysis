# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import pymc3 as pm
import theano

# %%
with open('seasons.pickle') as f:
    seasons = pickle.load(f)
for year, season in seasons.iteritems():
    print year,
    season.load_scores()

with open('season2018.pickle') as f:
    season18 = pickle.load(f)
season18.load_scores()

events = {}
for season in seasons.values():
    events.update(season.event_dict)
events.update(season18.event_dict)
# Out:
# 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017

# %%
skaters = {}
for discipline in ('men', 'ladies', 'pairs', 'dance'):
    skaters[discipline] = pd.read_csv('pd_data/results_nowd_nofra15_' + discipline + '.csv')

# %%
pairs18 = []
for event in season18.events:
    discipline = event.disciplines[2]
    segment = discipline.segments[1]
    for scorecard in segment.scorecards:
        pairs18.append({
            'Event': event.name,
            'Name': scorecard.skater.name,
            'Nation': scorecard.skater.country,
            'Points': scorecard.total_score,
            'Free PCS': scorecard.pcs,
            'Free TES': scorecard.tes
        })
pairs18 = pd.DataFrame(pairs18)

# %%
pairs_comp_type = skaters['pairs']

# %%
pairs_comp_type['is_gp'] = pairs_comp_type.apply(
    lambda row: 1 if 'gpfra' in row.Event or ('gp' in row.Event and 'gpf' not in row.Event) else 0,
    axis=1)

# %%
pairs_comp_type['is_ecfc'] = pairs_comp_type.apply(
    lambda row: 1 if row.Event[:2] == 'fc' or row.Event[:2] == 'ec' else 0,
    axis=1)

# %%
pairs_comp_type['is_champ'] = pairs_comp_type.apply(
    lambda row: 1 if row.Event[:2] == 'wc' or row.Event[:3] == 'owg' or ('gpfra' not in row.Event and 'gpf' in row.Event) 
                else 0,
    axis=1
)

# %%
history = pairs_comp_type[pairs_comp_type.Season != 2017]
individual_bests_short = {skater: np.max(map(float, history[history.Name == skater]['Short Score']))
                          for skater in history.Name.get_values()}
have_frees = history[history['Free Rank'] != 'DNQ']
have_frees = have_frees[have_frees['Free Rank'] != 'WD']
individual_bests_free = {skater: np.max(map(float, have_frees[have_frees.Name == skater]['Free Score']))
                         for skater in have_frees.Name.get_values()}
med_short = np.median(individual_bests_short.values())
med_free = np.median(individual_bests_free.values())

# %%
individual_bests = {skater: np.max(map(float, history[history.Name == skater].Points))
                    for skater in history.Name.get_values()}
med_points = np.median(individual_bests.values())
med_points
# Out:
# 145.33000000000001

# %%
data2017 = pairs_comp_type[pairs_comp_type.Season == 2017]
data2017['best_points'] = data2017.apply(
    lambda row: individual_bests.get(row.Name, med_points),
    axis=1
)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2017 = data2017[data2017['Free Rank'] != 'DNQ']
data2017 = data2017[data2017['Free Rank'] != 'WD']

# %%
X_gp = data2017.is_gp * data2017.best_points
X_ecfc = data2017.is_ecfc * data2017.best_points
X_champ = data2017.is_champ * data2017.best_points
Y = data2017['Free PCS']

# %%
np.sqrt(history.Points.var())
# Out:
# 40.208076277696897

# %%
with pm.Model() as model:

    # Priors for unknown model parameters
    alpha = pm.Normal('alpha', mu=0, sd=20)           # intercept
#     alpha_ecfc = pm.Normal('alpha_ecfc', mu=10, sd=20)
#     alpha_champ = pm.Normal('alpha_champ', mu=20, sd=20)
    beta_gp = pm.Normal('beta_gp', mu=0.0, sd=0.1)
    beta_ecfc = pm.Normal('beta_ecfc', mu=0.1, sd=0.1)
    beta_champ = pm.Normal('beta_champ', mu=0.2, sd=0.15)
    beta = pm.Normal('beta', mu=0.1, sd=0.15)
    sigma = pm.HalfNormal('sigma', sd=5)              # score variance
    
    # Expected value of outcome
    mu = (alpha + 
          beta_gp * X_gp + beta_ecfc * X_ecfc + beta_champ * X_champ + beta * data2017.best_points)

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal('Y_obs', mu=mu, sd=sigma, observed=Y)

# %%
# fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,4))
# axes[0].scatter(X1, Y)
# axes[1].scatter(X2, Y)
# axes[0].set_ylabel('Y'); axes[0].set_xlabel('X1'); axes[1].set_xlabel

# %%
with model:
    # draw 500 posterior samples
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:09<00:00, 100.32it/s]

# %%
# pm.traceplot(trace)

# %%
# pm.summary(trace)

# %%
# ppc = pm.sample_ppc(trace, samples=100, model=model, size=100)

# %%
elements = pd.read_csv('pd_data/elements_men.csv')
# spins = elements[elements.elt_type == 'sp']

# %%
# spins.head()

# %%
# plt.figure(figsize=(6,30))
# pm.forestplot(unpooled_trace, varnames=['mu_spins'])

# %%
len(unpooled_trace['mu_spins'][0])
# Out:
# 301

# %%
# unpooled_estimates.sort_values()

# %%
skaters = sorted(elements.skater.unique())
num_skaters = len(skaters)
skater_lookup = dict(zip(skaters, xrange(len(skaters))))

# %%
partial_pooling_results = {}

# %%
partial_pooling_models = {}

# %%
skater_theano = {}

# %%
for elt_type, prior_mu in (('sp', 2.5), ('ch', 1.), ('st', 3.), 
                           ('1j', 1.5), ('2j', 4.), ('3j', 6.), ('4j', 10.5)):
    elts = elements[elements.elt_type == elt_type]
    skater = elts['skater_code'] = elts.skater.replace(skater_lookup).values
    skater = theano.shared(skater)
    skater_theano[elt_type] = skater
    points = elts.points
    
    partial_pooling_results[elt_type] = {}
    partial_pooling = pm.Model()

    with partial_pooling:
        if elt_type == '1j':
            mu_g = pm.Exponential('mu_group_1j', lam=prior_mu)
        else:
            mu_g = pm.Normal('mu_group_' + elt_type, prior_mu, sd=1e5)
        sigma_g = pm.HalfCauchy('sigma_group' + elt_type, 5)
        
        mu = pm.Normal('mu_' + elt_type, mu=mu_g, sd=sigma_g, shape=num_skaters)
        sigma = pm.HalfCauchy('sigma_' + elt_type, 5)
        y = pm.Normal('y_' + elt_type, mu[skater], sd=sigma, observed=points)

    with partial_pooling:
        partial_pooling_trace = pm.sample()
    partial_pooling_results[elt_type] = partial_pooling_trace
    partial_pooling_models[elt_type] = partial_pooling
#     pm.traceplot(unpooled_trace)

#     estimates = pd.Series(partial_pooling_trace['mu_' + elt_type].mean(axis=0), index=skaters)
#     se = pd.Series(partial_pooling_trace['mu_' + elt_type].std(axis=0), index=skaters)

#     order = estimates.sort_values().index
#     plt.scatter(range(len(estimates)), unpooled_estimates[order])
#     for i, m, s in zip(range(len(estimates)), estimates[order], se[order]):
#         plt.plot([i,i], [m-s, m+s], 'b-')
#     plt.ylabel(elt_type + ' Points');plt.xlabel('Ordered Skater');
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:32<00:00, 31.02it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:15<00:00, 65.27it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [02:00<00:00,  8.32it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:07<00:00, 141.43it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:12<00:00, 78.60it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:36<00:00, 27.66it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:11<00:00, 87.40it/s]

# %%
def plot_trace(partial_pooling_trace, elt_type):
    estimates = pd.Series(partial_pooling_trace['mu_' + elt_type].mean(axis=0), index=skaters)
    se = pd.Series(partial_pooling_trace['mu_' + elt_type].std(axis=0), index=skaters)

    order = estimates.sort_values().index
    plt.scatter(range(len(estimates)), estimates[order])
    for i, m, s in zip(range(len(estimates)), estimates[order], se[order]):
        plt.plot([i,i], [m-s, m+s], 'b-')
    plt.ylabel(elt_type + ' Points');plt.xlabel('Ordered Skater');

# %%
for elt_type in ('ch', 'st', 'sp', '1j', '2j', '3j', '4j'):
    plot_trace(partial_pooling_results[elt_type], elt_type)
    plt.show()

# %%
nonmulti_trace_results
# Out:
# {'1j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 4 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 4 variables>},
#  '2j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  '3j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  '4j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  'ch': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  'sp': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  'st': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>}}

# %%
# sorted(zip(skaters, partial_pooling_results['3j']['mu_3j'].mean(axis=0)), key=lambda x: x[1])

# %%
ppc = {}
for elt_type in ('ch', 'st', 'sp', '1j', '2j', '3j', '4j'):
    with partial_pooling_models[elt_type]:
        skater_theano[elt_type].set_value(np.asarray(elements18[elements18.elt_type == elt_type].skater_code))
        ppc[elt_type] = pm.sample_ppc(partial_pooling_results[elt_type], model=partial_pooling_models[elt_type], samples=500)['y_' + elt_type]
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 1200.64it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1462.35it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1197.49it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1663.66it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1055.79it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1094.43it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1578.29it/s]

# %%
len(ppc['1j'][0])
# Out:
# 47

# %%
chelts = elements18[elements18.elt_type == 'ch']

# %%
plt.scatter(chelts.skater_code, chelts.points)

# %%
ELT_TYPES = ('ch', 'st', 'sp', '1j', '2j', '3j', '4j')

# %%
means = {}
for elt_type in ('ch', 'st', 'sp', '1j', '2j', '3j', '4j'):
    mean = ppc[elt_type].mean(axis=0)
    means[elt_type] = mean
    std = np.std(ppc[elt_type], axis=0)
    elt18elttype = elements18[elements18.elt_type == elt_type]
    order = pd.Series(mean).sort_values().index
    outcomes = []
    for index in order:
        outcomes.append(elt18elttype.iloc[index].points)
    plt.scatter(xrange(len(mean)), outcomes, color='r')
    plt.plot(xrange(len(mean)), [mean[x] for x in order])
    for i, m, s in zip(xrange(len(mean)), mean[order], std[order]):
        plt.plot([i,i], [m-s, m+s], 'b-')
    plt.ylabel(elt_type + ' Points');plt.xlabel('Ordered Skater');
    plt.show()

# %%
indices = {elt_type: 0 for elt_type in ELT_TYPES}
predictions_col = []
for index, row in elements18.iterrows():
    predictions_col.append(means[row.elt_type][indices[row.elt_type]])
    indices[row.elt_type] += 1

# %%
elements18['prediction'] = predictions_col

# %%
prev_skater = None
actual_tes = []
predicted_tes = []
for _, row in elements18[elements18.event == 'gprus2017'].iterrows():
    if row.skater == prev_skater:
        actual_tes[-1] += row.points
        predicted_tes[-1] += row.prediction
    else:
        actual_tes.append(row.points)
        predicted_tes.append(row.prediction)
        prev_skater = row.skater

# %%
zip(zip(actual_tes[12:], predicted_tes[12:]), elements18[elements18.segment == 'gprus2017 men_free'].skater.unique())
# Out:
# [((101.53999999999999, 92.14307821844989), 'Yuzuru HANYU'),
#  ((104.85000000000002, 97.65373825599332), 'Nathan CHEN'),
#  ((100.27, 93.07874384874333), 'Mikhail KOLYADA'),
#  ((85.38999999999999, 68.81319640493975), 'Misha GE'),
#  ((90.95, 77.67817824965869), 'Moris KVITELASHVILI'),
#  ((83.43, 79.87003049643734), 'Nam NGUYEN'),
#  ((73.56, 70.3640623670329), 'Dmitri ALIEV'),
#  ((62.99000000000001, 68.58667759693574), 'Denis TEN'),
#  ((65.28999999999999, 75.01421321252128), 'Deniss VASILJEVS'),
#  ((66.11, 74.4402414909266), 'Grant HOCHSTEIN'),
#  ((64.4, 64.68924035482132), 'Andrei LAZUKIN'),
#  ((52.39, 61.73916590193294), 'Daniel SAMOHIN')]

# %%
elements18[elements18.segment == 'gprus2017 men_free'].skater.unique()
# Out:
# array(['Yuzuru HANYU', 'Nathan CHEN', 'Mikhail KOLYADA', 'Misha GE',
#        'Moris KVITELASHVILI', 'Nam NGUYEN', 'Dmitri ALIEV', 'Denis TEN',
#        'Deniss VASILJEVS', 'Grant HOCHSTEIN', 'Andrei LAZUKIN',
#        'Daniel SAMOHIN'], dtype=object)

# %%
pd.DataFrame(fst).hist()
plt.axvline(x=8.49, color='r', linewidth=2)

# %%
elements18
# Out:
#       Unnamed: 0  bonus        date     element elt_type      event   goe  \
# 0              0  False  2017-10-22      4Lz+3T       4j  gprus2017  1.57
# 1              1  False  2017-10-22       FSSp4       sp  gprus2017  0.86
# 2              2  False  2017-10-22       CCSp3       sp  gprus2017  0.21
# 3              3   True  2017-10-22          4F       4j  gprus2017 -1.03
# 4              4   True  2017-10-22          3A       3j  gprus2017 -0.86
# 5              5  False  2017-10-22       StSq4       st  gprus2017  1.70
# 6              6  False  2017-10-22      CCoSp4       sp  gprus2017  1.14
# 7              7  False  2017-10-22        4Lo<       4j  gprus2017 -2.06
# 8              8  False  2017-10-22       FCSp4       sp  gprus2017  1.00
# 9              9  False  2017-10-22       CSSp4       sp  gprus2017  0.86
# 10            10   True  2017-10-22          3A       3j  gprus2017  3.00
# 11            11   True  2017-10-22       4T+3T       4j  gprus2017 -3.54
# 12            12  False  2017-10-22       StSq4       st  gprus2017  2.00
# 13            13  False  2017-10-22      CCoSp3       sp  gprus2017  1.07
# 14            14  False  2017-10-22      3Lz+3T       3j  gprus2017  0.80
# 15            15  False  2017-10-22          4T       4j  gprus2017  1.43
# 16            16  False  2017-10-22       CSSp4       sp  gprus2017  0.86
# 17            17   True  2017-10-22          3A       3j  gprus2017  0.57
# 18            18  False  2017-10-22       FCSp3       sp  gprus2017  0.21
# 19            19  False  2017-10-22       StSq4       st  gprus2017  1.00
# 20            20  False  2017-10-22      CCoSp4       sp  gprus2017  0.43
# 21            21  False  2017-10-22         3Lz       3j  gprus2017  0.90
# 22            22  False  2017-10-22    4T+COMBO       4j  gprus2017 -4.00
# 23            23  False  2017-10-22       FSSp4       sp  gprus2017  1.00
# 24            24   True  2017-10-22          3A       3j  gprus2017  2.14
# 25            25  False  2017-10-22       CCSp4       sp  gprus2017  1.00
# 26            26  False  2017-10-22       StSq4       st  gprus2017  0.90
# 27            27  False  2017-10-22      CCoSp4       sp  gprus2017  1.00
# 28            28  False  2017-10-22          3A       3j  gprus2017  0.14
# 29            29  False  2017-10-22      3Lz+3T       3j  gprus2017  0.70
# ...          ...    ...         ...         ...      ...        ...   ...
# 2550        2550   True  2018-01-27        3Lo<       3j     fc2018 -0.70
# 2551        2551  False  2018-01-27       ChSq1       ch     fc2018  0.50
# 2552        2552   True  2018-01-27          2A       2j     fc2018  0.21
# 2553        2553  False  2018-01-27       FSSp4       sp     fc2018  0.00
# 2554        2554  False  2018-01-27  3Lz+2T+2Lo       3j     fc2018 -0.30
# 2555        2555  False  2018-01-27         1Lo       1j     fc2018 -0.03
# 2556        2556  False  2018-01-27          3F       3j     fc2018 -2.10
# 2557        2557  False  2018-01-27     FCCoSp4       sp     fc2018  1.00
# 2558        2558  False  2018-01-27       StSq3       st     fc2018  0.86
# 2559        2559   True  2018-01-27          2A       2j     fc2018  0.71
# 2560        2560   True  2018-01-27         3Lz       3j     fc2018  0.80
# 2561        2561   True  2018-01-27      3F+REP       3j     fc2018 -2.10
# 2562        2562  False  2018-01-27       ChSq1       ch     fc2018  1.10
# 2563        2563   True  2018-01-27          1S       1j     fc2018 -0.04
# 2564        2564   True  2018-01-27          2A       2j     fc2018 -0.36
# 2565        2565  False  2018-01-27       CSSp3       sp     fc2018 -0.30
# 2566        2566  False  2018-01-27      CCoSp4       sp     fc2018  0.36
# 2567        2567  False  2018-01-27          2A       2j     fc2018 -1.00
# 2568        2568  False  2018-01-27      3Lo+2T       3j     fc2018  0.20
# 2569        2569  False  2018-01-27         3Fe       3j     fc2018 -1.40
# 2570        2570  False  2018-01-27       FSSp4       sp     fc2018  0.50
# 2571        2571  False  2018-01-27       StSq2       st     fc2018  0.07
# 2572        2572   True  2018-01-27         2Lz       2j     fc2018 -0.13
# 2573        2573   True  2018-01-27      2A+3T<       2j     fc2018 -0.93
# 2574        2574   True  2018-01-27         3Lo       3j     fc2018 -0.50
# 2575        2575   True  2018-01-27         3Lz       3j     fc2018 -2.10
# 2576        2576  False  2018-01-27     FCCoSp3       sp     fc2018  0.00
# 2577        2577   True  2018-01-27   2T+1Lo+2S       2j     fc2018  0.00
# 2578        2578  False  2018-01-27       ChSq1       ch     fc2018 -0.07
# 2579        2579  False  2018-01-27      CCoSp4       sp     fc2018  0.07
#
#      info  number  points              segment  segment_rank  \
# 0     NaN       1   19.47  gprus2017 men_short             1
# 1     NaN       2    3.86  gprus2017 men_short             1
# 2     NaN       3    3.01  gprus2017 men_short             1
# 3     NaN       4   12.50  gprus2017 men_short             1
# 4     NaN       5    8.49  gprus2017 men_short             1
# 5     NaN       6    5.60  gprus2017 men_short             1
# 6     NaN       7    4.64  gprus2017 men_short             1
# 7       <       1    6.34  gprus2017 men_short             2
# 8     NaN       2    4.20  gprus2017 men_short             2
# 9     NaN       3    3.86  gprus2017 men_short             2
# 10    NaN       4   12.35  gprus2017 men_short             2
# 11    NaN       5   12.52  gprus2017 men_short             2
# 12    NaN       6    5.90  gprus2017 men_short             2
# 13    NaN       7    4.07  gprus2017 men_short             2
# 14    NaN       1   11.10  gprus2017 men_short             3
# 15    NaN       2   11.73  gprus2017 men_short             3
# 16    NaN       3    3.86  gprus2017 men_short             3
# 17    NaN       4    9.92  gprus2017 men_short             3
# 18    NaN       5    3.01  gprus2017 men_short             3
# 19    NaN       6    4.90  gprus2017 men_short             3
# 20    NaN       7    3.93  gprus2017 men_short             3
# 21    NaN       1    6.90  gprus2017 men_short             4
# 22    NaN       2    6.30  gprus2017 men_short             4
# 23    NaN       3    4.00  gprus2017 men_short             4
# 24    NaN       4   11.49  gprus2017 men_short             4
# 25    NaN       5    4.20  gprus2017 men_short             4
# 26    NaN       6    4.80  gprus2017 men_short             4
# 27    NaN       7    4.50  gprus2017 men_short             4
# 28    NaN       1    8.64  gprus2017 men_short             5
# 29    NaN       2   11.00  gprus2017 men_short             5
# ...   ...     ...     ...                  ...           ...
# 2550    <      10    3.26      fc2018 men_free            22
# 2551  NaN      11    2.50      fc2018 men_free            22
# 2552  NaN      12    3.84      fc2018 men_free            22
# 2553  NaN      13    3.00      fc2018 men_free            22
# 2554  NaN       1    8.80      fc2018 men_free            23
# 2555  NaN       2    0.47      fc2018 men_free            23
# 2556  NaN       3    3.20      fc2018 men_free            23
# 2557  NaN       4    4.50      fc2018 men_free            23
# 2558  NaN       5    4.16      fc2018 men_free            23
# 2559  NaN       6    4.34      fc2018 men_free            23
# 2560  NaN       7    7.40      fc2018 men_free            23
# 2561  NaN       8    1.98      fc2018 men_free            23
# 2562  NaN       9    3.10      fc2018 men_free            23
# 2563  NaN      10    0.40      fc2018 men_free            23
# 2564  NaN      11    3.27      fc2018 men_free            23
# 2565  NaN      12    2.30      fc2018 men_free            23
# 2566  NaN      13    3.86      fc2018 men_free            23
# 2567  NaN       1    2.30      fc2018 men_free            24
# 2568  NaN       2    6.60      fc2018 men_free            24
# 2569    e       3    2.30      fc2018 men_free            24
# 2570  NaN       4    3.50      fc2018 men_free            24
# 2571  NaN       5    2.67      fc2018 men_free            24
# 2572  NaN       6    2.18      fc2018 men_free            24
# 2573    <       7    6.00      fc2018 men_free            24
# 2574  NaN       8    5.11      fc2018 men_free            24
# 2575  NaN       9    4.50      fc2018 men_free            24
# 2576  NaN      10    3.00      fc2018 men_free            24
# 2577  NaN      11    3.41      fc2018 men_free            24
# 2578  NaN      12    1.93      fc2018 men_free            24
# 2579  NaN      13    3.57      fc2018 men_free            24
#
#                    skater  start_order  skater_code  partial_pool_prediction
# 0             Nathan CHEN           10          205                12.647146
# 1             Nathan CHEN           10          205                 3.773436
# 2             Nathan CHEN           10          205                 3.734792
# 3             Nathan CHEN           10          205                12.459942
# 4             Nathan CHEN           10          205                 8.157336
# 5             Nathan CHEN           10          205                 4.524713
# 6             Nathan CHEN           10          205                 3.758024
# 7            Yuzuru HANYU           12          295                11.443672
# 8            Yuzuru HANYU           12          295                 3.907885
# 9            Yuzuru HANYU           12          295                 3.909596
# 10           Yuzuru HANYU           12          295                 8.980209
# 11           Yuzuru HANYU           12          295                10.996816
# 12           Yuzuru HANYU           12          295                 4.475097
# 13           Yuzuru HANYU           12          295                 3.951794
# 14           Dmitri ALIEV            8          149                 6.215006
# 15           Dmitri ALIEV            8          151                 8.668151
# 16           Dmitri ALIEV            8          171                 2.771548
# 17           Dmitri ALIEV            8          149                 6.128214
# 18           Dmitri ALIEV            8          171                 2.879499
# 19           Dmitri ALIEV            8          279                 2.704292
# 20           Dmitri ALIEV            8          171                 2.807221
# 21        Mikhail KOLYADA           11          193                 8.597168
# 22        Mikhail KOLYADA           11          193                10.192451
# 23        Mikhail KOLYADA           11          193                 3.901331
# 24        Mikhail KOLYADA           11          193                 8.655990
# 25        Mikhail KOLYADA           11          193                 3.934691
# 26        Mikhail KOLYADA           11          193                 4.327086
# 27        Mikhail KOLYADA           11          193                 3.954955
# 28               Misha GE            6          199                 7.109281
# 29               Misha GE            6          199                 7.131056
# ...                   ...          ...          ...                      ...
# 2550         Sihyeong LEE            5          254                 6.878232
# 2551         Sihyeong LEE            5          254                 2.399795
# 2552         Sihyeong LEE            5          254                 3.857384
# 2553         Sihyeong LEE            5          254                 3.286669
# 2554         Andrew DODDS            9           24                 4.954217
# 2555         Andrew DODDS            9           24                 0.849327
# 2556         Andrew DODDS            9           24                 5.263486
# 2557         Andrew DODDS            9           24                 2.592959
# 2558         Andrew DODDS            9           24                 3.226489
# 2559         Andrew DODDS            9           24                 3.256062
# 2560         Andrew DODDS            9           24                 5.377898
# 2561         Andrew DODDS            9           24                 5.401655
# 2562         Andrew DODDS            9           24                 2.662123
# 2563         Andrew DODDS            9           24                 0.851163
# 2564         Andrew DODDS            9           24                 3.125999
# 2565         Andrew DODDS            9           24                 2.603944
# 2566         Andrew DODDS            9           24                 2.655192
# 2567  Leslie Man Cheuk IP            1          158                 3.840877
# 2568  Leslie Man Cheuk IP            1          158                 5.302373
# 2569  Leslie Man Cheuk IP            1          158                 5.273166
# 2570  Leslie Man Cheuk IP            1          158                 2.955553
# 2571  Leslie Man Cheuk IP            1          158                 2.608227
# 2572  Leslie Man Cheuk IP            1          158                 3.816115
# 2573  Leslie Man Cheuk IP            1          158                 3.745656
# 2574  Leslie Man Cheuk IP            1          158                 5.072213
# 2575  Leslie Man Cheuk IP            1          158                 5.306959
# 2576  Leslie Man Cheuk IP            1          158                 3.022226
# 2577  Leslie Man Cheuk IP            1          158                 3.844992
# 2578  Leslie Man Cheuk IP            1          158                 2.269892
# 2579  Leslie Man Cheuk IP            1          158                 2.972517
#
# [2580 rows x 16 columns]

# %%
elements18 = pd.read_csv('pd_data/elements18_men.csv')

# %%
def get_idx(row):
    if row.skater not in skater_lookup:
        if row.elt_type == 'ch':
            return ch_replace
        if row.elt_type == 'st': 
            return st_replace
        if row.elt_type == 'sp':
            return sp_replace
        if row.elt_type == '1j':
            return j1_replace
        if row.elt_type == '2j':
            return j2_replace
        if row.elt_type == '3j':
            return j3_replace
        if row.elt_type == '4j':
            return j4_replace
    return skater_lookup[row.skater]

# %%
for skater in elements18.skater.unique():
    if skater not in skater_lookup:
        print skater
# Out:
# Dmitri ALIEV
# Andrei LAZUKIN
# Nicolas NADEAU
# Jun Hwan CHA
# Vincent ZHOU
# He ZHANG
# Kazuki TOMONO
# Hiroaki SATO
# Roman SADOVSKY
# Irakli MAYSURADZE
# Burak DEMIRBOGA
# Davide LEWTON BRAIN
# Yakau ZENKO
# Conor STAKELUM
# Donovan CARRILLO
# Geon Hyeong AN
# Micah Kai LYNETTE
# Harrison J-Ye WONG

# %%
for elt_type, trace in partial_pooling_results.iteritems():
    print elt_type
    estimates = pd.Series(trace['mu_' + elt_type].mean(axis=0), index=skaters)
    order = estimates.sort_values().index
    print order[len(order)/2]
# Out:
# ch
# Emanuel SANDHU
# sp
# Mark WEBSTER
# st
# Vaughn CHIPEUR
# 3j
# Konrad GIERING
# 4j
# Konstantin TUPIKOV
# 1j
# Michael DIMALANTA
# 2j
# Beka SHANKULASHVILI

# %%
ch_replace = skater_lookup['Emanuel SANDHU']
sp_replace = skater_lookup['Mark WEBSTER']
st_replace = skater_lookup['Vaughn CHIPEUR']
j3_replace = skater_lookup['Konrad GIERING']
j4_replace = skater_lookup['Konstantin TUPIKOV']
j1_replace = skater_lookup['Michael DIMALANTA']
j2_replace = skater_lookup['Beka SHANKULASHVILI']

# %%
elements18['skater_code'] = elements18.apply(get_idx, axis=1)

# %%
nonmulti_trace_results = {}
nonmulti_models = {}
nonmulti_skater_shared = {}

# %%
for elt_type, prior_mu in (('sp', 2.5), ('ch', 1.), ('st', 3.), 
                           ('1j', 1.5), ('2j', 4.), ('3j', 6.), ('4j', 10.5)):
    elts = elements[elements.elt_type == elt_type]
    skater = elts['skater_code'] = elts.skater.replace(skater_lookup).values
    skater = theano.shared(skater)
    nonmulti_skater_shared[elt_type] = skater
    points = elts.points
    
    nonmulti_trace_results[elt_type] = {}
    nonmulti_models[elt_type] = {}
    pooled_model = pm.Model()

    with pooled_model:
        if elt_type == '1j':
            mu = pm.Exponential('mu_1j', lam=prior_mu)
        else:
            mu = pm.Normal('mu_' + elt_type, prior_mu, sd=1e5)
        sigma = pm.HalfCauchy('sigma_' + elt_type, 5)
        y = pm.Normal('y_' + elt_type, mu, sd=sigma, observed=points)
        pooled_trace = pm.sample(tune=1000)

    pm.traceplot(pooled_trace)
    nonmulti_trace_results[elt_type]['pooled'] = pooled_trace
    nonmulti_models[elt_type]['pooled'] = pooled_model
    
    unpooled_model = pm.Model()

    with unpooled_model:
        if elt_type == '1j':
            mu = pm.Exponential('mu_1j', lam=prior_mu, shape=num_skaters)
        else:
            mu = pm.Normal('mu_' + elt_type, prior_mu, sd=1e5, shape=num_skaters)
        sigma = pm.HalfCauchy('sigma_' + elt_type, 5)
        y = pm.Normal('y_' + elt_type, mu[skater], sd=sigma, observed=points)
        unpooled_trace = pm.sample(tune=1000)

    pm.traceplot(unpooled_trace)
    nonmulti_trace_results[elt_type]['unpooled'] = unpooled_trace
    nonmulti_models[elt_type]['unpooled'] = unpooled_model
    plt.show()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:02<00:00, 674.59it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [02:10<00:00, 11.50it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:01<00:00, 1199.10it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:59<00:00, 25.11it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:01<00:00, 1058.47it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:28<00:00, 52.58it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:01<00:00, 1404.79it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:08<00:00, 184.63it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:02<00:00, 695.46it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [01:03<00:00, 23.48it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:03<00:00, 451.32it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [01:01<00:00, 24.34it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:01<00:00, 1313.91it/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1500/1500 [00:55<00:00, 27.23it/s]

# %%
with open('fits/men_nonmulti_elts.pickle') as f:
    (traces, models, skater_shared) = pickle.load(f)

# %%
elements_pred = pd.read_csv('fits/men_multi_elts_1.csv')

# %%
elements_pred.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  bonus        date element elt_type      event  \
# 0           0             0  False  2017-10-22  4Lz+3T       4j  gprus2017
# 1           1             1  False  2017-10-22   FSSp4       sp  gprus2017
# 2           2             2  False  2017-10-22   CCSp3       sp  gprus2017
# 3           3             3   True  2017-10-22      4F       4j  gprus2017
# 4           4             4   True  2017-10-22      3A       3j  gprus2017
#
#     goe info  number  points              segment  segment_rank       skater  \
# 0  1.57  NaN       1   19.47  gprus2017 men_short             1  Nathan CHEN
# 1  0.86  NaN       2    3.86  gprus2017 men_short             1  Nathan CHEN
# 2  0.21  NaN       3    3.01  gprus2017 men_short             1  Nathan CHEN
# 3 -1.03  NaN       4   12.50  gprus2017 men_short             1  Nathan CHEN
# 4 -0.86  NaN       5    8.49  gprus2017 men_short             1  Nathan CHEN
#
#    start_order  skater_code  partial_pool_prediction  pooled_prediction  \
# 0           10          205                12.647146           9.578746
# 1           10          205                 3.773436           3.062927
# 2           10          205                 3.734792           3.062927
# 3           10          205                12.459942           9.578746
# 4           10          205                 8.157336           6.923761
#
#    unpooled_prediction
# 0            13.102899
# 1             3.787730
# 2             3.787730
# 3            13.102899
# 4             8.681645

# %%
unpooled_estimates = {
    elt_type: pd.Series(traces[elt_type]['unpooled_trace']['mu_' + elt_type].mean(axis=0), index=skaters)
    for elt_type in ELT_TYPES
}
unpooled_medians = {elt_type: np.median(unpooled_estimates[elt_type]) for elt_type in ELT_TYPES}

# %%
elements_pred['pooled_prediction'] = elements_pred.apply(lambda row: traces[row.elt_type]['pooled_trace']['mu_' + row.elt_type].mean(axis=0), axis=1)

# %%
elements_pred['unpooled_prediction'] = elements_pred.apply(
    lambda row: unpooled_medians[row.elt_type] if row.skater not in skater_lookup else unpooled_estimates[row.elt_type].ix[row.skater],
    axis=1
)

# %%
elements_pred.to_csv('fits/men_multi_elts_1.csv')

# %%
nonmulti_traces
# Out:
# {'1j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 4 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 4 variables>},
#  '2j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  '3j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  '4j': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  'ch': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  'sp': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>},
#  'st': {'pooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>,
#   'unpooled_trace': <MultiTrace: 1 chains, 500 iterations, 3 variables>}}

# %%
# Make predictions.
ppc_pooled = {}
ppc_unpooled = {}
for elt_type in ('ch', 'st', 'sp', '2j', '3j', '4j'):
    print elt_type
    with nonmulti_models[elt_type]['pooled']:
        ppc_pooled[elt_type] = pm.sample_ppc(nonmulti_traces[elt_type]['pooled_trace'])['y_' + elt_type]
    with nonmulti_models[elt_type]['unpooled']:
        nonmulti_skater_shared[elt_type].set_value(
            np.asarray(elements18[elements18.elt_type == elt_type].skater_code))
        ppc_unpooled[elt_type] = pm.sample_ppc(nonmulti_traces[elt_type]['unpooled_trace'])['y_' + elt_type]
# Out:
#  26%|██▌       | 131/500 [00:00<00:00, 1307.57it/s]
# ch
# 100%|██████████| 500/500 [00:00<00:00, 1088.99it/s]
# 100%|██████████| 500/500 [00:10<00:00, 46.59it/s]
#  21%|██        | 105/500 [00:00<00:00, 1048.70it/s]
# st
# 100%|██████████| 500/500 [00:00<00:00, 982.03it/s]
# 100%|██████████| 500/500 [00:10<00:00, 46.83it/s]
#  38%|███▊      | 191/500 [00:00<00:00, 1902.35it/s]
# sp
# 100%|██████████| 500/500 [00:00<00:00, 1672.62it/s]
# 100%|██████████| 500/500 [00:09<00:00, 53.62it/s]
#   0%|          | 1/500 [00:00<00:50,  9.81it/s]
# 2j
# 100%|██████████| 500/500 [00:00<00:00, 999.83it/s]
# 100%|██████████| 500/500 [00:09<00:00, 54.09it/s]
#   6%|▋         | 32/500 [00:00<00:01, 319.29it/s]
# 3j
# 100%|██████████| 500/500 [00:00<00:00, 1030.39it/s]
# 100%|██████████| 500/500 [00:08<00:00, 61.70it/s]
#  14%|█▍        | 72/500 [00:00<00:00, 707.12it/s]
# 4j
# 100%|██████████| 500/500 [00:00<00:00, 1316.06it/s]
# 100%|██████████| 500/500 [00:07<00:00, 64.01it/s]

# %%
ppc_unpooled.keys()
# Out:
# ['ch', 'sp', 'st']

# %%
ppc_pooled['ch']
# Out:
# array([  5.24914902e+04,   2.17139730e+04,   6.33713139e+04,
#          3.49453485e+04,   9.99272092e+04,   3.85294654e+04,
#          1.02883090e+05,   8.31013718e+04,   5.11099991e+04,
#          1.07648137e+05,  -1.74071633e+05,  -1.86001343e+04,
#          2.27910231e+05,   6.95166227e+04,   8.61331657e+03,
#         -2.65893600e+05,   6.97518493e+04,   2.90397553e+04,
#         -1.00851252e+05,   1.13836003e+05,   1.54027989e+05,
#         -1.56504303e+05,  -2.13972899e+05,  -1.70340673e+04,
#         -1.37927449e+05,  -1.62689078e+04,  -1.90149459e+04,
#         -4.66004325e+03,  -1.29719791e+05,  -4.93687711e+04,
#          1.65793766e+04,   1.10940402e+05,  -5.21789458e+04,
#          2.74867897e+04,   5.65404910e+04,  -2.07548894e+04,
#          7.92055121e+04,   6.38970017e+04,   1.09850821e+05,
#          8.48438996e+03,  -6.16830542e+04,   2.69951734e+05,
#         -3.87833953e+04,   6.02492237e+04,   5.71204241e+03,
#         -7.41770330e+04,   1.35085355e+05,  -6.45114268e+04,
#         -2.43007611e+04,   9.45188043e+04,  -8.01861882e+04,
#          1.40913150e+05,   5.45716837e+04,  -9.51360080e+04,
#          2.01041912e+05,  -2.48852564e+04,  -1.36290058e+05,
#          1.97967712e+04,   1.37192606e+05,  -9.02099904e+04,
#         -1.29200519e+04,   5.51494801e+04,  -1.05630490e+05,
#          1.89956818e+05,   1.37582863e+05,   1.66058597e+04,
#          2.12957706e+05,   1.54757167e+05,   2.54308837e+04,
#          4.22993699e+04,  -2.51059838e+02,  -1.22885703e+05,
#         -1.16012177e+04,   1.84874384e+04,  -3.77154585e+03,
#         -5.73268957e+04,   1.08362014e+04,   7.17503296e+04,
#         -1.29446441e+05,  -8.51669016e+04,  -2.30437452e+04,
#          1.68430525e+04,   8.62069266e+04,  -3.55099909e+04,
#          6.18695619e+04,   3.65197630e+04,  -1.11111330e+05,
#          3.89047221e+04,   1.34114396e+05,  -5.15065993e+04,
#          4.76872271e+03,   3.26682397e+04,  -6.60472762e+04,
#         -1.14549209e+05,   3.14902774e+04,   4.04156432e+04,
#         -7.79975537e+02,  -1.43544393e+05,   1.90666230e+05,
#          1.08954662e+05,  -2.79145620e+04,   3.47571115e+04,
#         -1.27583266e+05,   2.13011270e+05,   1.27788037e+05,
#          2.02422840e+05,   7.68988845e+04,  -3.83638128e+04,
#          9.80173641e+04,   2.30787322e+04,   9.63449791e+04,
#         -7.26310815e+04,   2.17369221e+05,  -3.36138821e+04,
#         -2.52510878e+04,   1.15299471e+05,   4.40136271e+04,
#          1.26154762e+05,   3.80523127e+05,   5.60101557e+04,
#         -4.46990637e+04,   1.16186886e+05,   8.61428022e+04,
#          4.93617986e+04,  -1.82387717e+04,  -2.27151314e+04,
#          1.66693436e+05,  -2.78884201e+05,  -1.06783791e+05,
#          1.38282221e+05,   4.86966767e+04,  -8.02748843e+04,
#          9.80691536e+04,   2.18900360e+04,  -3.10264603e+04,
#          6.02391260e+04,  -2.22251110e+05,   2.01379223e+05,
#          2.05550553e+03,   1.28797838e+05,  -5.17784286e+04,
#         -1.04389168e+05,   7.65832691e+04,   5.20691372e+03,
#         -3.79000738e+04,   1.03827787e+04,  -1.15328484e+04,
#          4.48499918e+04,   9.99682082e+04,   1.15927324e+05,
#          4.95892092e+04,  -2.87858488e+04,   6.08539892e+04,
#          1.37512350e+05,  -1.11638078e+05,   3.90584652e+04,
#          1.25707076e+05,  -1.68211891e+05,  -2.03217776e+03,
#         -1.22691607e+04,  -4.92601021e+04,   1.56858702e+05,
#          2.06609821e+04,  -6.12878916e+04,   5.47178423e+03,
#          3.38127389e+04,  -1.61277706e+03,   1.10956659e+05,
#         -5.71278452e+04,  -1.02442151e+05,   6.65010604e+04,
#          3.06149435e+04,  -9.42280835e+04,  -1.10250932e+05,
#          1.86671384e+05,  -1.00461896e+05,  -4.01423698e+04,
#         -1.59617075e+05,   9.63679925e+04,   9.13257895e+04,
#          6.07034638e+04,  -2.65061418e+04,  -5.76904450e+04,
#          6.40279372e+04,   3.86697496e+03,  -5.16002346e+04,
#          3.64450244e+04,  -1.10434198e+05,   7.12493901e+04,
#         -3.07258660e+04,  -2.87509953e+04,  -2.30880136e+05,
#          7.72044233e+04,   4.44528647e+04,   1.07600297e+05,
#         -2.86349034e+03,  -2.31333814e+05,  -5.89785075e+04,
#          8.26130875e+04,  -1.00420312e+05,   7.12809296e+04,
#         -6.04783517e+04,   5.55583427e+04,   6.63837241e+04,
#         -1.29214294e+05,  -4.30521305e+04,  -1.22895697e+04,
#         -1.18904579e+04,   1.64665490e+05,   2.38787104e+05,
#          1.06520036e+05,  -4.49394094e+04,   1.06417521e+04,
#         -6.02456383e+04,  -6.85216600e+04,   4.69346604e+04,
#         -1.47325567e+04,   2.74041503e+05,   1.35398669e+04,
#         -3.99328701e+04,  -4.68858781e+04,  -1.85498212e+05,
#          2.25587985e+05,   3.57351224e+03,  -8.48475469e+04,
#         -1.94217632e+05,  -2.55468057e+04,   1.05652693e+05,
#         -1.88870526e+05,   6.11560892e+04,  -6.20812214e+04,
#          7.56171270e+04,  -1.07736535e+04,   8.32102623e+04,
#         -7.43999908e+04,   2.07357208e+05,  -1.86425747e+05,
#          2.53284120e+04,   1.39353809e+04,  -3.02517778e+05,
#         -1.10063581e+05,  -4.41171556e+04,  -9.49568852e+04,
#          9.84693554e+04,  -1.97302394e+05,  -8.07947327e+04,
#          6.78961855e+04,  -1.58693584e+05,   8.22048146e+04,
#          4.24758207e+03,   1.54702762e+05,  -2.41606750e+05,
#         -1.42016711e+05,   1.28455248e+03,  -6.26701514e+04,
#         -1.59452269e+04,   1.21367239e+05,  -1.24273106e+04,
#          2.14176348e+03,   1.58905859e+05,  -3.96684177e+04,
#         -1.80589285e+05,   3.24022312e+04,  -1.56841369e+05,
#         -4.30922630e+04,   8.13154216e+04,  -4.12832454e+04,
#          6.33781051e+04,   4.02844656e+04,  -2.27179559e+04,
#         -6.50552402e+04,   2.14604315e+05,   4.84139904e+04,
#          4.47605182e+04,  -9.90733853e+04,  -3.75886235e+04,
#         -8.81939871e+04,  -1.13969097e+05,   3.07075026e+04,
#          5.80038364e+04,   1.59806512e+05,   2.61137005e+04,
#         -2.04331526e+05,   7.34732490e+04,   3.68184793e+04,
#          7.07188061e+04,  -7.22693888e+04,   1.08363776e+05,
#          4.84055845e+04,  -9.23641592e+04,   6.61962552e+04,
#          4.43368810e+04,   1.29183769e+05,  -2.21259071e+05,
#         -7.38299920e+04,  -1.10694708e+05,   2.44905688e+04,
#         -4.70293238e+04,  -1.56228876e+05,   8.51512460e+04,
#         -1.86581161e+05,  -4.40252589e+04,  -5.47651050e+04,
#         -6.53388427e+03,   3.43421547e+04,  -1.66775386e+05,
#         -2.38136442e+04,  -6.57187426e+04,   3.00126747e+04,
#          1.49659760e+05,  -3.05977608e+04,   1.65206059e+04,
#         -1.02776788e+05,  -7.47640237e+04,   1.18050726e+05,
#         -1.14307574e+05,  -3.18640956e+03,  -2.83030052e+05,
#          1.03405627e+05,   1.52984080e+05,   1.16305624e+05,
#         -6.52814205e+04,   9.55413296e+04,   3.17973192e+04,
#          4.60045524e+04,  -4.81901253e+04,  -6.95554815e+04,
#          9.46904355e+04,   6.81871808e+04,   1.20379840e+05,
#          1.52547092e+05,  -9.16896768e+03,  -8.11607273e+04,
#         -1.20676373e+05,  -9.13746781e+04,   2.98061504e+05,
#         -8.46076008e+04,  -7.68273686e+04,  -6.71284939e+04,
#         -7.73657958e+04,  -3.78801684e+04,  -1.62685092e+05,
#          1.68352078e+05,  -4.91934473e+04,   1.84091108e+04,
#          1.04119081e+05,   6.03587539e+04,   1.46591119e+04,
#          4.88215524e+04,   9.16062281e+04,   1.41312010e+05,
#          1.40227968e+05,   3.94996831e+04,   2.11025610e+04,
#          5.25502734e+04,   1.89349775e+05,  -3.73302916e+04,
#          9.64675323e+04,  -1.95962838e+05,   3.36467145e+04,
#         -1.13969186e+05,  -1.13319043e+05,  -9.64110641e+04,
#         -1.69707335e+05,   4.79267953e+04,   2.70300744e+05,
#          3.30113436e+04,  -7.28967825e+04,  -3.90200558e+03,
#         -3.84149585e+04,   2.00357289e+05,  -1.42650125e+05,
#         -1.18258187e+05,   1.48645227e+05,   4.31222334e+04,
#          8.40694690e+04,   9.24505106e+04,   2.84931555e+05,
#          5.43023533e+04,   1.13967121e+04,  -9.95563428e+03,
#         -6.02051156e+04,   1.46409786e+05,   1.57149585e+05,
#          6.10500787e+04,  -1.05022386e+05,   4.56141794e+01,
#          5.70949690e+04,   1.57662886e+05,  -8.11681229e+03,
#          9.68624605e+04,   1.62372426e+05,   4.77757686e+04,
#          3.03046189e+04,  -6.43642398e+04,   7.91122686e+04,
#          5.46260083e+04,  -1.04263904e+04,  -1.08130871e+04,
#         -2.32509523e+05,   1.15375697e+05,  -2.57992976e+04,
#         -1.71194109e+04,   1.22846437e+05,  -1.20059281e+05,
#          2.18153249e+05,  -8.53894356e+04,   2.72317071e+04,
#          1.88390067e+05,  -1.13103466e+05,   8.11918130e+04,
#         -2.74278059e+04,   5.37678609e+04,   1.17461188e+05,
#         -6.09603198e+04,   6.36760738e+04,  -1.85462423e+04,
#         -2.51605057e+04,  -1.42546126e+05,   1.47487632e+04,
#          4.25413406e+04,   1.25902770e+05,   3.26251347e+04,
#          9.69504073e+04,  -7.38455514e+03,   1.79910995e+05,
#          1.01108258e+05,   6.18617262e+04,   4.57502840e+04,
#          1.54936119e+05,   1.35696224e+04,  -1.14932480e+05,
#         -6.21624966e+04,   3.04222332e+04,   4.07410884e+04,
#          1.72099992e+04,   6.64002757e+04,   3.36960961e+04,
#         -1.30250170e+05,  -3.78759269e+04,   1.08475053e+04,
#          2.80987170e+04,  -1.36375131e+05,  -7.77957968e+03,
#          7.49474002e+04,   6.46531944e+04,   1.57020122e+05,
#         -1.45681452e+05,   1.20741427e+05,  -7.52187068e+03,
#         -3.01230658e+04,   1.16176404e+05,   3.93644992e+04,
#          9.04384811e+04,  -4.97711970e+04,  -9.62600219e+04,
#          2.43110299e+04,   1.09444262e+04,   1.02204911e+05,
#         -6.65071456e+04,   2.33232779e+04,   8.57611711e+04,
#          1.00179476e+04,   3.47324284e+04,   9.86638333e+04,
#          9.84341014e+04,  -1.17814551e+04,  -2.96877520e+04,
#         -8.34525849e+04,  -4.14924864e+04,  -4.96841148e+04,
#         -7.79498292e+04,   9.73791619e+04,  -1.05259521e+05,
#         -5.95687871e+04,  -1.65659514e+05,   1.08153482e+05,
#          2.71522871e+05,  -1.21599197e+05,  -4.94187830e+04,
#          9.19553728e+04,  -7.74301285e+04,  -7.73903037e+04,
#          1.58469147e+05,  -1.00830988e+05,  -1.28940882e+05,
#          1.47379017e+05,  -1.10276191e+05,  -8.79205078e+04,
#          1.02943332e+05,   4.02505572e+04,   6.89079608e+04,
#          2.26487674e+05,   1.78801110e+05,  -5.05705209e+04,
#         -1.61486339e+05,   1.04672061e+05,  -3.58062853e+04,
#          5.91421304e+03,  -1.28353743e+05])

# %%
means = {}
for elt_type in ('ch', 'st', 'sp', '2j', '3j', '4j'):
    mean = ppc_pooled[elt_type].mean(axis=0)
    means[elt_type] = mean
    std = np.std(ppc_pooled[elt_type], axis=0)
    elt18elttype = elements18[elements18.elt_type == elt_type]
    order = pd.Series(mean).sort_values().index
    outcomes = []
    for index in order:
        outcomes.append(elt18elttype.iloc[index].points)
    plt.scatter(xrange(len(mean)), outcomes, color='r')
    plt.plot(xrange(len(mean)), [mean[x] for x in order])
    for i, m, s in zip(xrange(len(mean)), mean[order], std[order]):
        plt.plot([i,i], [m-s, m+s], 'b-')
    plt.ylabel(elt_type + ' Points');plt.xlabel('Ordered Skater');
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-280-16d5370d3e97> in <module>()
#       9     for index in order:
#      10         outcomes.append(elt18elttype.iloc[index].points)
# ---> 11     plt.scatter(xrange(len(mean)), outcomes, color='r')
#      12     plt.plot(xrange(len(mean)), [mean[x] for x in order])
#      13     for i, m, s in zip(xrange(len(mean)), mean[order], std[order]):
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
means = {}
for elt_type in ('ch', 'st', 'sp', '2j', '3j', '4j'):
    mean = ppc_unpooled[elt_type].mean(axis=0)
    means[elt_type] = mean
    std = np.std(ppc_unpooled[elt_type], axis=0)
    elt18elttype = elements18[elements18.elt_type == elt_type]
    order = pd.Series(mean).sort_values().index
    outcomes = []
    for index in order:
        outcomes.append(elt18elttype.iloc[index].points)
    plt.scatter(xrange(len(mean)), outcomes, color='r')
    plt.plot(xrange(len(mean)), [mean[x] for x in order])
    for i, m, s in zip(xrange(len(mean)), mean[order], std[order]):
        plt.plot([i,i], [m-s, m+s], 'b-')
    plt.ylabel(elt_type + ' Points');plt.xlabel('Ordered Skater');
    plt.show()

# %%
elements18.to_csv('fits/men_multi_elts_1.csv')
