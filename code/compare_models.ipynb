# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %%
with open('season2018.pickle') as f:
    season2018 = pickle.load(f)

# %%
elements_pred = pd.read_csv('fits/men_multi_elts_1.csv')
components_pred = pd.read_csv('fits/men_multi_comp_1.csv')

# %%
len(components_pred[components_pred.points > components_pred.partial_pool_predictions])
# Out:
# 1226

# %%
len(components_pred)
# Out:
# 1320

# %%
elements_pred.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  bonus        date element  \
# 0           0             0               0  False  2017-10-22  4Lz+3T
# 1           1             1               1  False  2017-10-22   FSSp4
# 2           2             2               2  False  2017-10-22   CCSp3
# 3           3             3               3   True  2017-10-22      4F
# 4           4             4               4   True  2017-10-22      3A
#
#   elt_type      event   goe info  number  points              segment  \
# 0       4j  gprus2017  1.57  NaN       1   19.47  gprus2017 men_short
# 1       sp  gprus2017  0.86  NaN       2    3.86  gprus2017 men_short
# 2       sp  gprus2017  0.21  NaN       3    3.01  gprus2017 men_short
# 3       4j  gprus2017 -1.03  NaN       4   12.50  gprus2017 men_short
# 4       3j  gprus2017 -0.86  NaN       5    8.49  gprus2017 men_short
#
#    segment_rank       skater  start_order  skater_code  \
# 0             1  Nathan CHEN           10          205
# 1             1  Nathan CHEN           10          205
# 2             1  Nathan CHEN           10          205
# 3             1  Nathan CHEN           10          205
# 4             1  Nathan CHEN           10          205
#
#    partial_pool_prediction  pooled_prediction  unpooled_prediction
# 0                12.647146           9.578746            13.102899
# 1                 3.773436           3.062927             3.787730
# 2                 3.734792           3.062927             3.787730
# 3                12.459942           9.578746            13.102899
# 4                 8.157336           6.923761             8.681645

# %%
# 2018 data
men = pd.read_csv('pd_data/results18_men.csv')
ladies = pd.read_csv('pd_data/results18_ladies.csv')
pairs = pd.read_csv('pd_data/results18_pairs.csv')
dance = pd.read_csv('pd_data/results18_dance.csv')

# %%
with open('season2018.pickle') as f:
    season18 = pickle.load(f)
season18.load_scores()

# %%
history = pd.read_csv('pd_data/results_nowd_nofra15_men.csv')

# %%
def get_comparison(estimate_type):
    comparison = []
    for event in season2018.events:
        event_name = event.name
        elts = elements_pred[elements_pred.event == event_name].groupby('skater')[estimate_type].sum()
        comp_short = components_pred[components_pred.segment == event_name + ' men_short'].groupby('skater')[estimate_type + 's'].sum()
        comp_free = 2 * components_pred[components_pred.segment == event_name + ' men_free'].groupby('skater')[estimate_type + 's'].sum()
        predictions = {}
        outcomes = {}
        total_score = elts + comp_short
        for skater in total_score.index:
            predictions[skater] = total_score.ix[skater]
            if skater in comp_free.index:
                predictions[skater] += comp_free.ix[skater]
        for index, row in men[men.Event == event_name][['Name', 'Points']].iterrows():
            outcomes[row.Name] = row.Points
        comparison.append((predictions, outcomes))
    return comparison

# %%
def get_ranks(result_dict):
    ranks = {}
    for (i, (skater, _)) in enumerate(sorted(result_dict.iteritems(), key=lambda (k,v): -1 * v)):
        ranks[skater] = i+1
    return ranks

# %%
def calculate_loss(comparison):
    score_difference = 0.
    rank_mistake = 0
    rank_miss = {}
    for i, (predictions, outcomes) in enumerate(comparison):
        for skater in predictions:
            score_difference += (predictions[skater] - outcomes[skater])**2
            if pd.isnull(score_difference):
                print i, skater
        predicted_ranks = get_ranks(predictions)
        actual_ranks = get_ranks(outcomes)
        for skater in predictions:
            diff = abs(predicted_ranks[skater] - actual_ranks[skater])
            if diff:
                if skater not in rank_miss:
                    rank_miss[skater] = []
                rank_miss[skater].append((predicted_ranks[skater], actual_ranks[skater]))
                rank_mistake += diff
    return score_difference, rank_mistake, rank_miss

# %%
score_differences = {}
rank_mistakes = {}
rank_misses = {}
for estimate_type in ('pooled_prediction', 'unpooled_prediction', 'partial_pool_prediction'):
    comparison = get_comparison(estimate_type)
    score_difference, rank_mistake, rank_miss = calculate_loss(comparison)
    score_differences[estimate_type] = score_difference
    rank_mistakes[estimate_type] = rank_mistake
    rank_misses[estimate_type] = rank_miss

# %%
rank_mistakes, score_differences
# Out:
# ({'partial_pool_prediction': 302,
#   'pooled_prediction': 376,
#   'unpooled_prediction': 380},
#  {'partial_pool_prediction': 91053.292305282477,
#   'pooled_prediction': 204946.19175774002,
#   'unpooled_prediction': 140457656.8769297})

# %%
with open('fits/men_reputation_start_pred.csv') as f:
    short_pred, free_pred = pickle.load(f)

# %%
men.Event.unique()
# Out:
# array(['gprus2017', 'gpcan2017', 'gpchn2017', 'gpjpn2017', 'gpfra2017',
#        'gpusa2017', 'gpf1718', 'ec2018', 'fc2018'], dtype=object)

# %%
individual_bests_short = {skater: np.max(map(float, history[history.Name == skater]['Short Score']))
                          for skater in history.Name.get_values()}
len(individual_bests_short)
# Out:
# 300

# %%
have_frees = history[history['Free Rank'] != 'DNQ']
have_frees = have_frees[have_frees['Free Rank'] != 'WD']
individual_bests_free = {skater: np.max(map(float, have_frees[have_frees.Name == skater]['Free Score']))
                         for skater in have_frees.Name.get_values()}
len(individual_bests_free)
# Out:
# 238

# %%
med_short = np.median(individual_bests_short.values())
med_free = np.median(individual_bests_free.values())
med_short, med_free
# Out:
# (61.090000000000003, 124.88)

# %%
men['Short Best'] = men.apply(lambda row: med_short if row.Name not in individual_bests_short else individual_bests_short[row.Name], axis=1)
men['Free Best'] = men.apply(lambda row: med_free if row.Name not in individual_bests_free else individual_bests_free[row.Name], axis=1)

# %%
men.head()
# Out:
#    Unnamed: 0  Rank      Event        Date                 Name Nation  \
# 0           0     1  gprus2017  2017-10-22          Nathan CHEN    USA
# 1           1     2  gprus2017  2017-10-22         Yuzuru HANYU    JPN
# 2           2     3  gprus2017  2017-10-22      Mikhail KOLYADA    RUS
# 3           3     4  gprus2017  2017-10-22             Misha GE    UZB
# 4           4     5  gprus2017  2017-10-22  Moris KVITELASHVILI    GEO
#
#    Points  Short Rank  Short Score Free Rank Free Score  Short Start  \
# 0  293.79           1       100.54         2     193.25           10
# 1  290.77           2        94.85         1     195.92           12
# 2  271.06           4        85.79         3     185.27           11
# 3  255.33           5        85.02         4     170.31            6
# 4  250.26           8        80.67         5     169.59            2
#
#    Free Start  Num Short Scorecards  Num Free Scorecards  Short Best  \
# 0        12.0                    12                   12      103.12
# 1        11.0                    12                   12      110.95
# 2         8.0                    12                   12       93.28
# 3         7.0                    12                   12       82.25
# 4         5.0                    12                   12       76.85
#
#    Free Best
# 0     204.34
# 1     223.20
# 2     178.31
# 3     163.54
# 4     162.90

# %%
def predict_short(row):
    prediction = 20.8236
    best = med_short
    if row.Name in individual_bests_short:
        best = individual_bests_short[row.Name]
    prediction += 0.6155 * best
    return prediction + 12.3222 * float(row['Short Start']) / row['Num Short Scorecards']

def predict_free(row):
    if pd.isnull(row['Free Start']):
        return 0.
    prediction = 72.3915 
    best = med_free
    if row.Name in individual_bests_free:
        best = individual_bests_free[row.Name]
    prediction += 0.3983 * best
    return prediction + 35.2871 * float(row['Free Start']) / row['Num Free Scorecards']

# %%
men['pred_ols_short'] = men.apply(predict_short, axis=1)

# %%
men['pred_ols_free'] = men.apply(predict_free, axis=1)

# %%
ols_comparison = []
for event in season2018.events:
    competition = men[men.Event == event.name]
    predictions = {}
    outcomes = {}
    for index, row in competition.iterrows():
        predictions[row.Name] = row.pred_ols_short + row.pred_ols_free
    for index, row in competition.iterrows():
        outcomes[row.Name] = row.Points
    ols_comparison.append((predictions, outcomes))

# %%
score_difference_ols, rank_misses_ols, rank_mistake_ols = calculate_loss(ols_comparison)
score_differences['ols'] = score_difference_ols
rank_misses['ols'] = rank_misses_ols
rank_mistakes['ols'] = rank_mistake_ols

# %%
score_differences
# Out:
# {'ols': 50237.52214114873,
#  'partial_pool_prediction': 91053.292305282477,
#  'pooled_prediction': 204946.19175774002,
#  'unpooled_prediction': 140457656.8769297}

# %%
rank_mistakes
# Out:
# {'ols': 308,
#  'partial_pool_prediction': 302,
#  'pooled_prediction': 376,
#  'unpooled_prediction': 380}

# %%
def get_comparison_combined(df):
    comparison = []
    comparison_programs = []
    for event in season2018.events:
        # Predictions for this event.
        predictions = {}; outcomes = {}
        short_pred = {}; short_outcome = {}
        free_pred = {}; free_outcome = {}
        
        event_name = event.name
        short = df[df.segment == event_name + ' men_short']
        free = df[df.segment == event_name + ' men_free']
        
        # Predict elements and components
        short_elts = short[short.is_elt == 1].groupby('skater').prediction.sum()
        free_elts = free[free.is_elt == 1].groupby('skater').prediction.sum()
        comp_short = short[short.is_elt == 0].groupby('skater').prediction.sum()
        comp_free = 2 * free[free.is_elt == 0].groupby('skater').prediction.sum()

        # Predict total scores.
        short_score = short_elts + comp_short
        free_score = free_elts + comp_free
        total_score = short_score + free_score
        for skater in total_score.index:
            predictions[skater] = short_score.ix[skater]
            short_pred[skater] = short_score.ix[skater]
            if skater in free_score.index:
                predictions[skater] += free_score.ix[skater]
                free_pred[skater] = free_score.ix[skater]
        for index, row in men[men.Event == event_name][['Name', 'Points', 'Short Score', 'Free Score']].iterrows():
            outcomes[row.Name] = row.Points
            short_outcome[row.Name] = row['Short Score']
            if not pd.isnull(row['Free Score']):
                free_outcome[row.Name] = row['Free Score']
        comparison.append((predictions, outcomes))
        comparison_programs.append((short_pred, short_outcome, free_pred, free_outcome))
    return comparison, comparison_programs

# %%
score_differences['prediction2'], rank_mistakes['prediction2'], rank_misses['prediction2'] = calculate_loss(get_comparison_combined(predictions2)[0])

# %%
get_comparison_combined(predictions2)[1]
# Out:
# [({'Andrei LAZUKIN': 63.671315225140006,
#    'Daniel SAMOHIN': 70.449969969609995,
#    'Denis TEN': 80.448933857850008,
#    'Deniss VASILJEVS': 74.894249014769997,
#    'Dmitri ALIEV': 62.77371994157,
#    'Grant HOCHSTEIN': 74.054346166889999,
#    'Mikhail KOLYADA': 83.997503447059984,
#    'Misha GE': 74.459112829250003,
#    'Moris KVITELASHVILI': 75.45644624082,
#    'Nam NGUYEN': 78.579096597190002,
#    'Nathan CHEN': 91.440426214209992,
#    'Yuzuru HANYU': 94.74895394987},
#   {'Andrei LAZUKIN': 78.54,
#    'Daniel SAMOHIN': 62.02,
#    'Denis TEN': 69.0,
#    'Deniss VASILJEVS': 82.44,
#    'Dmitri ALIEV': 88.77,
#    'Grant HOCHSTEIN': 67.56,
#    'Mikhail KOLYADA': 85.79,
#    'Misha GE': 85.02,
#    'Moris KVITELASHVILI': 80.67,
#    'Nam NGUYEN': 80.74,
#    'Nathan CHEN': 100.54,
#    'Yuzuru HANYU': 94.85},
#   {'Andrei LAZUKIN': 128.59292752707,
#    'Daniel SAMOHIN': 135.62300495433101,
#    'Denis TEN': 150.81385262985799,
#    'Deniss VASILJEVS': 150.07281262237001,
#    'Dmitri ALIEV': 134.32823151555002,
#    'Grant HOCHSTEIN': 149.49316524277,
#    'Mikhail KOLYADA': 173.43801525107,
#    'Misha GE': 145.61114743318001,
#    'Moris KVITELASHVILI': 147.20977027987999,
#    'Nam NGUYEN': 152.47505864764,
#    'Nathan CHEN': 181.72919374463999,
#    'Yuzuru HANYU': 185.68936272181998},
#   {'Andrei LAZUKIN': '133.6',
#    'Daniel SAMOHIN': '121.77',
#    'Denis TEN': '145.35',
#    'Deniss VASILJEVS': '145.09',
#    'Dmitri ALIEV': '150.84',
#    'Grant HOCHSTEIN': '138.53',
#    'Mikhail KOLYADA': '185.27',
#    'Misha GE': '170.31',
#    'Moris KVITELASHVILI': '169.59',
#    'Nam NGUYEN': '157.71',
#    'Nathan CHEN': '193.25',
#    'Yuzuru HANYU': '195.92'}),
#  ({'Alexander SAMARIN': 77.748320489400001,
#    'Brendan KERRY': 64.223679833900007,
#    'Jason BROWN': 85.032751301079998,
#    'Jorik HENDRICKX': 74.306824610109999,
#    'Jun Hwan CHA': 63.248719563169999,
#    'Keegan MESSING': 66.618290081609999,
#    'Michal BREZINA': 76.595447136199994,
#    'Nicolas NADEAU': 63.197456754370002,
#    'Patrick CHAN': 89.15705770739001,
#    'Paul FENTZ': 69.872365677689999,
#    'Shoma UNO': 92.189536010099999,
#    'Takahito MURA': 78.750455808849992},
#   {'Alexander SAMARIN': 84.02,
#    'Brendan KERRY': 63.19,
#    'Jason BROWN': 90.71,
#    'Jorik HENDRICKX': 82.08,
#    'Jun Hwan CHA': 68.46,
#    'Keegan MESSING': 82.17,
#    'Michal BREZINA': 80.34,
#    'Nicolas NADEAU': 74.23,
#    'Patrick CHAN': 94.43,
#    'Paul FENTZ': 68.48,
#    'Shoma UNO': 103.62,
#    'Takahito MURA': 74.82},
#   {'Alexander SAMARIN': 152.06040271135001,
#    'Brendan KERRY': 123.67417425192102,
#    'Jason BROWN': 157.949138293152,
#    'Jorik HENDRICKX': 142.4900679827,
#    'Jun Hwan CHA': 132.07052121186001,
#    'Keegan MESSING': 130.84087558330498,
#    'Michal BREZINA': 158.10434171847001,
#    'Nicolas NADEAU': 123.125394871965,
#    'Patrick CHAN': 164.83430886946002,
#    'Paul FENTZ': 138.55455648276001,
#    'Shoma UNO': 188.61545180882001,
#    'Takahito MURA': 142.68549788279},
#   {'Alexander SAMARIN': '166.04',
#    'Brendan KERRY': '138.37',
#    'Jason BROWN': '170.43',
#    'Jorik HENDRICKX': '155.23',
#    'Jun Hwan CHA': '141.86',
#    'Keegan MESSING': '135.58',
#    'Michal BREZINA': '156.7',
#    'Nicolas NADEAU': '155.2',
#    'Patrick CHAN': '151.27',
#    'Paul FENTZ': '133.12',
#    'Shoma UNO': '197.48',
#    'Takahito MURA': '111.84'}),
#  ({'Alexander MAJOROV': 65.515826948890009,
#    'Alexander PETROV': 74.754485100890008,
#    'Boyang JIN': 87.886181745440012,
#    'Grant HOCHSTEIN': 74.480621527159997,
#    'Han YAN': 78.737910989379998,
#    'He ZHANG': 54.341181865355992,
#    'Javier FERNANDEZ': 87.63497886127999,
#    'Keiji TANAKA': 74.849392905810006,
#    'Kevin REYNOLDS': 76.306381615359996,
#    'Max AARON': 82.061960448200011,
#    'Mikhail KOLYADA': 85.522806822539991,
#    'Vincent ZHOU': 65.746368657540003},
#   {'Alexander MAJOROV': 64.27,
#    'Alexander PETROV': 68.58,
#    'Boyang JIN': 93.89,
#    'Grant HOCHSTEIN': 80.55,
#    'Han YAN': 82.22,
#    'He ZHANG': 46.99,
#    'Javier FERNANDEZ': 90.57,
#    'Keiji TANAKA': 87.19,
#    'Kevin REYNOLDS': 64.4,
#    'Max AARON': 83.11,
#    'Mikhail KOLYADA': 103.13,
#    'Vincent ZHOU': 80.23},
#   {'Alexander MAJOROV': 123.50681841714999,
#    'Alexander PETROV': 150.48306151360001,
#    'Boyang JIN': 182.77918488629001,
#    'Grant HOCHSTEIN': 138.95690205409301,
#    'Han YAN': 159.41956255512002,
#    'He ZHANG': 123.37853474457,
#    'Javier FERNANDEZ': 171.64468538451001,
#    'Keiji TANAKA': 145.94842564416001,
#    'Kevin REYNOLDS': 141.74744121153,
#    'Max AARON': 162.20229075899999,
#    'Mikhail KOLYADA': 159.34504799811899,
#    'Vincent ZHOU': 138.89498320696998},
#   {'Alexander MAJOROV': '121.77',
#    'Alexander PETROV': '117.44',
#    'Boyang JIN': '170.59',
#    'Grant HOCHSTEIN': '135.89',
#    'Han YAN': '172.39',
#    'He ZHANG': '120.59',
#    'Javier FERNANDEZ': '162.49',
#    'Keiji TANAKA': '159.98',
#    'Kevin REYNOLDS': '162.1',
#    'Max AARON': '176.58',
#    'Mikhail KOLYADA': '176.25',
#    'Vincent ZHOU': '176.43'}),
#  ({'Adam RIPPON': 79.879160966970005,
#    'Alexei BYCHENKO': 73.602625290440002,
#    'Deniss VASILJEVS': 74.731044151230009,
#    'Dmitri ALIEV': 65.825162571199996,
#    'Hiroaki SATO': 63.116914827519999,
#    'Jason BROWN': 84.932159363570008,
#    'Kazuki TOMONO': 63.127737103500003,
#    'Keegan MESSING': 66.870894818599993,
#    'Michal BREZINA': 76.538172339269991,
#    'Nam NGUYEN': 78.416737092899993,
#    'Sergei VORONOV': 77.316423259399997},
#   {'Adam RIPPON': 84.95,
#    'Alexei BYCHENKO': 85.52,
#    'Deniss VASILJEVS': 76.51,
#    'Dmitri ALIEV': 77.51,
#    'Hiroaki SATO': 75.95,
#    'Jason BROWN': 85.36,
#    'Kazuki TOMONO': 79.88,
#    'Keegan MESSING': 80.13,
#    'Michal BREZINA': 76.24,
#    'Nam NGUYEN': 65.82,
#    'Sergei VORONOV': 90.06},
#   {'Adam RIPPON': 161.43285979211998,
#    'Alexei BYCHENKO': 144.59654360041,
#    'Deniss VASILJEVS': 135.15247740556998,
#    'Dmitri ALIEV': 128.14181824256002,
#    'Hiroaki SATO': 126.34106978006201,
#    'Jason BROWN': 164.05941080024002,
#    'Kazuki TOMONO': 132.39588184663,
#    'Keegan MESSING': 131.99473206368,
#    'Michal BREZINA': 153.27613821034001,
#    'Nam NGUYEN': 145.56496423486999,
#    'Sergei VORONOV': 153.78651157867},
#   {'Adam RIPPON': '177.04',
#    'Alexei BYCHENKO': '166.55',
#    'Deniss VASILJEVS': '158.29',
#    'Dmitri ALIEV': '145.94',
#    'Hiroaki SATO': '123.25',
#    'Jason BROWN': '160.59',
#    'Kazuki TOMONO': '152.05',
#    'Keegan MESSING': '155.67',
#    'Michal BREZINA': '144.21',
#    'Nam NGUYEN': '148.69',
#    'Sergei VORONOV': '181.06'}),
#  ({'Alexander SAMARIN': 76.734169721950011,
#    'Alexei BYCHENKO': 73.480090041140002,
#    'Denis TEN': 79.066890118239996,
#    'Javier FERNANDEZ': 91.66902863560999,
#    'Kevin AYMOZ': 68.096023294489996,
#    'Max AARON': 81.716240867500005,
#    'Misha GE': 74.293713566720001,
#    'Moris KVITELASHVILI': 76.104715997390002,
#    'Romain PONSART': 64.394094027889992,
#    'Shoma UNO': 91.891714863869993,
#    'Vincent ZHOU': 65.439819847439992},
#   {'Alexander SAMARIN': 91.51,
#    'Alexei BYCHENKO': 86.79,
#    'Denis TEN': 83.7,
#    'Javier FERNANDEZ': 107.86,
#    'Kevin AYMOZ': 70.0,
#    'Max AARON': 78.64,
#    'Misha GE': 85.41,
#    'Moris KVITELASHVILI': 86.98,
#    'Romain PONSART': 63.81,
#    'Shoma UNO': 93.92,
#    'Vincent ZHOU': 66.12},
#   {'Alexander SAMARIN': 152.19331592570001,
#    'Alexei BYCHENKO': 140.19585670231999,
#    'Denis TEN': 153.02681807593001,
#    'Javier FERNANDEZ': 183.70584536059999,
#    'Kevin AYMOZ': 134.02043174815998,
#    'Max AARON': 153.63512578850998,
#    'Misha GE': 145.24954388192,
#    'Moris KVITELASHVILI': 137.75993482461001,
#    'Romain PONSART': 119.603650521452,
#    'Shoma UNO': 188.72626381027999,
#    'Vincent ZHOU': 127.983310244005},
#   {'Alexander SAMARIN': '161.62',
#    'Alexei BYCHENKO': '160.65',
#    'Denis TEN': '144.87',
#    'Javier FERNANDEZ': '175.85',
#    'Kevin AYMOZ': '150.43',
#    'Max AARON': '158.56',
#    'Misha GE': '172.93',
#    'Moris KVITELASHVILI': '153.52',
#    'Romain PONSART': '134.31',
#    'Shoma UNO': '179.4',
#    'Vincent ZHOU': '156.09'}),
#  ({'Adam RIPPON': 80.38700075093999,
#    'Boyang JIN': 76.079319814030995,
#    'Daniel SAMOHIN': 74.536606792279997,
#    'Han YAN': 78.377043796129996,
#    'Kevin REYNOLDS': 69.97867723844,
#    'Liam FIRUS': 67.759287562090009,
#    'Maxim KOVTUN': 84.682805338160009,
#    'Nathan CHEN': 90.941691761780007,
#    'Roman SADOVSKY': 62.979371524339996,
#    'Ross MINER': 68.945956296361999,
#    'Sergei VORONOV': 76.630860279469999,
#    'Takahito MURA': 78.183165402910006},
#   {'Adam RIPPON': 89.04,
#    'Boyang JIN': 77.97,
#    'Daniel SAMOHIN': 82.28,
#    'Han YAN': 85.97,
#    'Kevin REYNOLDS': 69.1,
#    'Liam FIRUS': 65.17,
#    'Maxim KOVTUN': 64.98,
#    'Nathan CHEN': 104.12,
#    'Roman SADOVSKY': 70.85,
#    'Ross MINER': 71.59,
#    'Sergei VORONOV': 87.51,
#    'Takahito MURA': 75.05},
#   {'Adam RIPPON': 157.91579771711002,
#    'Boyang JIN': 180.52431781368,
#    'Han YAN': 152.76843186137899,
#    'Kevin REYNOLDS': 149.30934627171001,
#    'Liam FIRUS': 130.68618819607002,
#    'Nathan CHEN': 169.21537839052502,
#    'Roman SADOVSKY': 117.267073310683,
#    'Ross MINER': 143.945547648499,
#    'Sergei VORONOV': 153.97190288872002,
#    'Takahito MURA': 141.39776315605201},
#   {'Adam RIPPON': '177.41',
#    'Boyang JIN': '168.06',
#    'Daniel SAMOHIN': 'DNQ',
#    'Han YAN': '142.36',
#    'Kevin REYNOLDS': '134.95',
#    'Liam FIRUS': '145.66',
#    'Maxim KOVTUN': 'DNQ',
#    'Nathan CHEN': '171.76',
#    'Roman SADOVSKY': '129.25',
#    'Ross MINER': '148.03',
#    'Sergei VORONOV': '169.98',
#    'Takahito MURA': '137.72'}),
#  ({'Adam RIPPON': 80.241654864910004,
#    'Jason BROWN': 84.710194789799999,
#    'Mikhail KOLYADA': 85.894558075020001,
#    'Nathan CHEN': 91.546794255400002,
#    'Sergei VORONOV': 76.514410455589996,
#    'Shoma UNO': 91.794541249359995},
#   {'Adam RIPPON': 86.19,
#    'Jason BROWN': 89.02,
#    'Mikhail KOLYADA': 99.22,
#    'Nathan CHEN': 103.32,
#    'Sergei VORONOV': 87.77,
#    'Shoma UNO': 101.51},
#   {'Adam RIPPON': 157.23316952600999,
#    'Jason BROWN': 163.40855744149999,
#    'Mikhail KOLYADA': 166.46325066205702,
#    'Nathan CHEN': 185.98745571516,
#    'Sergei VORONOV': 153.92790862330997,
#    'Shoma UNO': 189.93022799715004},
#   {'Adam RIPPON': '168.14',
#    'Jason BROWN': '164.79',
#    'Mikhail KOLYADA': '182.78',
#    'Nathan CHEN': '183.19',
#    'Sergei VORONOV': '178.82',
#    'Shoma UNO': '184.5'}),
#  ({'Alexander MAJOROV': 67.118871766460003,
#    'Alexander MASZLJANKO': 43.590502544633999,
#    'Alexander SAMARIN': 77.38995101818,
#    'Alexei BYCHENKO': 73.549275338299992,
#    'Burak DEMIRBOGA': 61.07191804448,
#    'Chafik BESSEGHIER': 68.631540550629992,
#    'Conor STAKELUM': 52.308894822862001,
#    'Daniel Albert NAURITS': 57.941887074060006,
#    'Daniel SAMOHIN': 74.503429367850003,
#    'Davide LEWTON BRAIN': 57.527465431290004,
#    'Deniss VASILJEVS': 74.874007290900011,
#    'Dmitri ALIEV': 63.469546907240002,
#    'Felipe MONTOYA': 62.25859605054,
#    'Igor REZNICHENKO': 57.901232000019995,
#    'Irakli MAYSURADZE': 57.649167264689993,
#    'Javier FERNANDEZ': 91.393935601359999,
#    'Jiri BELOHRADSKY': 57.514702638789998,
#    'Jorik HENDRICKX': 74.233617385590009,
#    'Larry LOUPOLOVER': 49.421655090139993,
#    'Matteo RIZZO': 66.589802265119999,
#    'Michael NEUMAN': 47.232157714220001,
#    'Michal BREZINA': 76.008361792380001,
#    'Mikhail KOLYADA': 79.024660588049997,
#    'Moris KVITELASHVILI': 75.409102668169993,
#    'Nicholas VRDOLJAK': 54.812845496770002,
#    'Nicky OBREYKOV': 55.758227403730004,
#    'Paul FENTZ': 68.899659468240003,
#    'Phillip HARRIS': 64.252358677209997,
#    'Romain PONSART': 61.025826886259992,
#    'Slavik HAYRAPETYAN': 55.546435934049995,
#    'Sondre ODDVOLL BOE': 56.552199965130001,
#    'Stephane WALKER': 59.939750226139992,
#    'Thomas KENNES': 53.550099399460009,
#    'Valtter VIRTANEN': 55.695101529099993,
#    'Yakau ZENKO': 54.676449471789994,
#    'Yaroslav PANIOT': 70.68340912586001},
#   {'Alexander MAJOROV': 71.28,
#    'Alexander MASZLJANKO': 52.01,
#    'Alexander SAMARIN': 74.25,
#    'Alexei BYCHENKO': 74.97,
#    'Burak DEMIRBOGA': 61.27,
#    'Chafik BESSEGHIER': 70.35,
#    'Conor STAKELUM': 43.05,
#    'Daniel Albert NAURITS': 60.76,
#    'Daniel SAMOHIN': 59.18,
#    'Davide LEWTON BRAIN': 54.64,
#    'Deniss VASILJEVS': 85.11,
#    'Dmitri ALIEV': 91.33,
#    'Felipe MONTOYA': 61.23,
#    'Igor REZNICHENKO': 63.96,
#    'Irakli MAYSURADZE': 63.69,
#    'Javier FERNANDEZ': 103.82,
#    'Jiri BELOHRADSKY': 58.3,
#    'Jorik HENDRICKX': 78.56,
#    'Larry LOUPOLOVER': 52.44,
#    'Matteo RIZZO': 78.26,
#    'Michael NEUMAN': 57.44,
#    'Michal BREZINA': 72.72,
#    'Mikhail KOLYADA': 83.41,
#    'Moris KVITELASHVILI': 76.74,
#    'Nicholas VRDOLJAK': 58.3,
#    'Nicky OBREYKOV': 50.24,
#    'Paul FENTZ': 72.54,
#    'Phillip HARRIS': 67.77,
#    'Romain PONSART': 61.45,
#    'Slavik HAYRAPETYAN': 69.49,
#    'Sondre ODDVOLL BOE': 61.85,
#    'Stephane WALKER': 65.96,
#    'Thomas KENNES': 54.65,
#    'Valtter VIRTANEN': 60.23,
#    'Yakau ZENKO': 47.26,
#    'Yaroslav PANIOT': 60.07},
#   {'Alexander MAJOROV': 140.03035862764,
#    'Alexander SAMARIN': 152.37470378114,
#    'Alexei BYCHENKO': 148.66707441551,
#    'Burak DEMIRBOGA': 115.339858368335,
#    'Chafik BESSEGHIER': 144.91323841766001,
#    'Daniel Albert NAURITS': 116.199078292265,
#    'Deniss VASILJEVS': 149.44061036159002,
#    'Dmitri ALIEV': 125.97575518153002,
#    'Felipe MONTOYA': 122.41352442905,
#    'Igor REZNICHENKO': 111.16516648277801,
#    'Irakli MAYSURADZE': 126.51786666241999,
#    'Javier FERNANDEZ': 179.74065013741,
#    'Jorik HENDRICKX': 139.92417519397901,
#    'Matteo RIZZO': 129.80837079148,
#    'Michal BREZINA': 153.19450816032003,
#    'Mikhail KOLYADA': 172.42533027798001,
#    'Moris KVITELASHVILI': 135.398286062762,
#    'Paul FENTZ': 133.37135149269,
#    'Phillip HARRIS': 124.61593925273999,
#    'Romain PONSART': 125.35659630668999,
#    'Slavik HAYRAPETYAN': 106.47762695946,
#    'Sondre ODDVOLL BOE': 112.44067874353999,
#    'Stephane WALKER': 119.15800085893,
#    'Valtter VIRTANEN': 113.32143255964999},
#   {'Alexander MAJOROV': '154.58',
#    'Alexander MASZLJANKO': 'DNQ',
#    'Alexander SAMARIN': '155.56',
#    'Alexei BYCHENKO': '163.47',
#    'Burak DEMIRBOGA': '105.95',
#    'Chafik BESSEGHIER': '140.82',
#    'Conor STAKELUM': 'DNQ',
#    'Daniel Albert NAURITS': '115.34',
#    'Daniel SAMOHIN': 'DNQ',
#    'Davide LEWTON BRAIN': 'DNQ',
#    'Deniss VASILJEVS': '158.41',
#    'Dmitri ALIEV': '182.73',
#    'Felipe MONTOYA': '120.49',
#    'Igor REZNICHENKO': '101.69',
#    'Irakli MAYSURADZE': '127.53',
#    'Javier FERNANDEZ': '191.73',
#    'Jiri BELOHRADSKY': 'DNQ',
#    'Jorik HENDRICKX': '139.61',
#    'Larry LOUPOLOVER': 'DNQ',
#    'Matteo RIZZO': '141.17',
#    'Michael NEUMAN': 'DNQ',
#    'Michal BREZINA': '152.48',
#    'Mikhail KOLYADA': '175.49',
#    'Moris KVITELASHVILI': '133.73',
#    'Nicholas VRDOLJAK': 'DNQ',
#    'Nicky OBREYKOV': 'DNQ',
#    'Paul FENTZ': '122.43',
#    'Phillip HARRIS': '140.45',
#    'Romain PONSART': '139.27',
#    'Slavik HAYRAPETYAN': '127.14',
#    'Sondre ODDVOLL BOE': '108.79',
#    'Stephane WALKER': '119.45',
#    'Thomas KENNES': 'DNQ',
#    'Valtter VIRTANEN': '121.54',
#    'Yakau ZENKO': 'DNQ',
#    'Yaroslav PANIOT': 'DNQ'}),
#  ({'Abzal RAKIMGALIEV': 62.11148182046999,
#    'Andrew DODDS': 55.138683304880004,
#    'Boyang JIN': 87.425822591710002,
#    'Brendan KERRY': 69.87094366765001,
#    'Chih-I TSAO': 59.912033934169997,
#    'Denis TEN': 79.046274106480013,
#    'Donovan CARRILLO': 57.620736183689999,
#    'Elladj BALDE': 70.380783596170005,
#    'Geon Hyeong AN': 55.280695356376995,
#    'Grant HOCHSTEIN': 74.255628944000009,
#    'Han YAN': 78.344182217490015,
#    'Harrison J-Ye WONG': 57.972313857370004,
#    'Harry Hau Yin LEE': 42.76339114772,
#    'He ZHANG': 57.401779911849999,
#    'Jason BROWN': 85.345342320209994,
#    'Julian Zhi Jie YEE': 64.502777266919992,
#    'June Hyoung LEE': 62.046100215609997,
#    'Kai Xiang CHEW': 42.842267694293,
#    'Keiji TANAKA': 75.689639185920015,
#    'Kevin REYNOLDS': 76.650747389070006,
#    'Leslie Man Cheuk IP': 50.207848704550003,
#    'Mark WEBSTER': 52.946488330867993,
#    'Max AARON': 78.966713456660017,
#    'Micah Kai LYNETTE': 57.53702893082,
#    'Micah TANG': 43.930970889549997,
#    'Misha GE': 73.835178726530003,
#    'Nam NGUYEN': 76.366281633919996,
#    'Shoma UNO': 91.870871596740002,
#    'Sihyeong LEE': 65.205734124369997,
#    'Takahito MURA': 71.316620381109999},
#   {'Abzal RAKIMGALIEV': 60.77,
#    'Andrew DODDS': 63.69,
#    'Boyang JIN': 100.17,
#    'Brendan KERRY': 79.57,
#    'Chih-I TSAO': 72.57,
#    'Denis TEN': 75.3,
#    'Donovan CARRILLO': 59.07,
#    'Elladj BALDE': 75.17,
#    'Geon Hyeong AN': 56.67,
#    'Grant HOCHSTEIN': 70.8,
#    'Han YAN': 84.74,
#    'Harrison J-Ye WONG': 52.78,
#    'Harry Hau Yin LEE': 43.98,
#    'He ZHANG': 63.62,
#    'Jason BROWN': 89.78,
#    'Julian Zhi Jie YEE': 68.45,
#    'June Hyoung LEE': 69.93,
#    'Kai Xiang CHEW': 50.92,
#    'Keiji TANAKA': 90.68,
#    'Kevin REYNOLDS': 74.65,
#    'Leslie Man Cheuk IP': 53.8,
#    'Mark WEBSTER': 49.45,
#    'Max AARON': 84.15,
#    'Micah Kai LYNETTE': 53.29,
#    'Micah TANG': 43.05,
#    'Misha GE': 82.27,
#    'Nam NGUYEN': 84.09,
#    'Shoma UNO': 100.49,
#    'Sihyeong LEE': 62.65,
#    'Takahito MURA': 76.66},
#   {'Abzal RAKIMGALIEV': 126.28931537692,
#    'Andrew DODDS': 103.34606688151999,
#    'Boyang JIN': 181.77003932564998,
#    'Brendan KERRY': 134.27318711223,
#    'Chih-I TSAO': 122.20673754819001,
#    'Denis TEN': 155.27634036631298,
#    'Donovan CARRILLO': 120.49627773146003,
#    'Elladj BALDE': 137.85181059797,
#    'Geon Hyeong AN': 123.35379901756001,
#    'Grant HOCHSTEIN': 149.08601177132999,
#    'Han YAN': 152.82465491265799,
#    'He ZHANG': 120.078817604525,
#    'Jason BROWN': 163.69629770413999,
#    'Julian Zhi Jie YEE': 127.73765873217002,
#    'June Hyoung LEE': 124.15676366915,
#    'Keiji TANAKA': 150.47869459228002,
#    'Kevin REYNOLDS': 156.66584649975999,
#    'Leslie Man Cheuk IP': 98.912129732289998,
#    'Max AARON': 159.63770389793001,
#    'Misha GE': 145.97753474401998,
#    'Nam NGUYEN': 152.62893628389998,
#    'Shoma UNO': 188.12699835465003,
#    'Sihyeong LEE': 121.33978893614,
#    'Takahito MURA': 154.68343790778999},
#   {'Abzal RAKIMGALIEV': '114.81',
#    'Andrew DODDS': '114.12',
#    'Boyang JIN': '200.78',
#    'Brendan KERRY': '140.38',
#    'Chih-I TSAO': '122.64',
#    'Denis TEN': '135.52',
#    'Donovan CARRILLO': '126.84',
#    'Elladj BALDE': '163.03',
#    'Geon Hyeong AN': '123.59',
#    'Grant HOCHSTEIN': '155.59',
#    'Han YAN': '143.19',
#    'Harrison J-Ye WONG': 'DNQ',
#    'Harry Hau Yin LEE': 'DNQ',
#    'He ZHANG': '121.2',
#    'Jason BROWN': '179.44',
#    'Julian Zhi Jie YEE': '129.23',
#    'June Hyoung LEE': '141.93',
#    'Kai Xiang CHEW': 'DNQ',
#    'Keiji TANAKA': '169.63',
#    'Kevin REYNOLDS': '166.85',
#    'Leslie Man Cheuk IP': '96.43',
#    'Mark WEBSTER': 'DNQ',
#    'Max AARON': '171.3',
#    'Micah Kai LYNETTE': 'DNQ',
#    'Micah TANG': 'DNQ',
#    'Misha GE': '166.69',
#    'Nam NGUYEN': '153.43',
#    'Shoma UNO': '197.45',
#    'Sihyeong LEE': '114.42',
#    'Takahito MURA': '148.75'})]

# %%
comps = predictions2[predictions2.is_elt == 0]
len(comps[comps.points > comps.prediction]), len(comps)
# Out:
# (981, 1320)

# %%
fancy_short_pred = {men.Event.unique()[i]: (get_comparison_combined(predictions2)[1][i][0], get_comparison_combined(predictions2)[1][i][1]) for i in xrange(9)}

# %%
compare = men[['pred_ols_short', 'Name', 'Event']].copy()

# %%
compare['pred2_short'] = compare.apply(lambda row: fancy_short_pred[row.Event][0][row.Name], axis=1)

# %%
compare['real_short'] = compare.apply(lambda row: fancy_short_pred[row.Event][1][row.Name], axis=1)

# %%
sum(map(lambda x: x * x, compare['pred_ols_short'] - compare['pred2_short']))
# Out:
# 5694.2237378707268

# %%
compare
# Out:
#      pred_ols_short                 Name      Event  pred2_short  real_short
# 0         94.562460          Nathan CHEN  gprus2017    91.440426      100.54
# 1        101.435525         Yuzuru HANYU  gprus2017    94.748954       94.85
# 2         89.532790      Mikhail KOLYADA  gprus2017    83.997503       85.79
# 3         77.609575             Misha GE  gprus2017    74.459113       85.02
# 4         70.178475  Moris KVITELASHVILI  gprus2017    75.456446       80.67
# 5         66.639295         Dmitri ALIEV  gprus2017    62.773720       88.77
# 6         73.937110           Nam NGUYEN  gprus2017    78.579097       80.74
# 7         78.316365     Deniss VASILJEVS  gprus2017    74.894249       82.44
# 8         83.983105            Denis TEN  gprus2017    80.448934       69.00
# 9         59.451345       Andrei LAZUKIN  gprus2017    63.671315       78.54
# 10        76.391920      Grant HOCHSTEIN  gprus2017    74.054346       67.56
# 11        81.441035       Daniel SAMOHIN  gprus2017    70.449970       62.02
# 12        97.687130            Shoma UNO  gpcan2017    92.189536      103.62
# 13        88.395150          Jason BROWN  gpcan2017    85.032751       90.71
# 14        77.618780    Alexander SAMARIN  gpcan2017    77.748320       84.02
# 15        94.979965         Patrick CHAN  gpcan2017    89.157058       94.43
# 16        79.817150      Jorik HENDRICKX  gpcan2017    74.306825       82.08
# 17        81.972435       Michal BREZINA  gpcan2017    76.595447       80.34
# 18        60.478195       Nicolas NADEAU  gpcan2017    63.197457       74.23
# 19        63.168965       Keegan MESSING  gpcan2017    66.618290       82.17
# 20        62.531895         Jun Hwan CHA  gpcan2017    63.248720       68.46
# 21        69.383445           Paul FENTZ  gpcan2017    69.872366       68.48
# 22        77.112055        Brendan KERRY  gpcan2017    64.223680       63.19
# 23        81.813440        Takahito MURA  gpcan2017    78.750456       74.82
# 24        89.532790      Mikhail KOLYADA  gpchn2017    85.522807      103.13
# 25        91.805020           Boyang JIN  gpchn2017    87.886182       93.89
# 26        83.410635            Max AARON  gpchn2017    82.061960       83.11
# 27        64.585595         Vincent ZHOU  gpchn2017    65.746369       80.23
# 28        80.412170              Han YAN  gpchn2017    78.737911       82.22
# 29       100.266075     Javier FERNANDEZ  gpchn2017    87.634979       90.57
# ..              ...                  ...        ...          ...         ...
# 112       92.215760           Boyang JIN     fc2018    87.425823      100.17
# 113       97.687130            Shoma UNO     fc2018    91.870872      100.49
# 114       89.627370          Jason BROWN     fc2018    85.345342       89.78
# 115       82.276655         Keiji TANAKA     fc2018    75.689639       90.68
# 116       85.258965            Max AARON     fc2018    78.966713       84.15
# 117       81.716975             Misha GE     fc2018    73.835179       82.27
# 118       81.865120       Kevin REYNOLDS     fc2018    76.650747       74.65
# 119       69.876880         Elladj BALDE     fc2018    70.380784       75.17
# 120       79.687470           Nam NGUYEN     fc2018    76.366282       84.09
# 121       85.751790              Han YAN     fc2018    78.344182       84.74
# 122       79.061730      Grant HOCHSTEIN     fc2018    74.255629       70.80
# 123       84.688620        Takahito MURA     fc2018    71.316620       76.66
# 124       78.960385        Brendan KERRY     fc2018    69.870944       79.57
# 125       68.457515      June Hyoung LEE     fc2018    62.046100       69.93
# 126       89.117355            Denis TEN     fc2018    79.046274       75.30
# 127       71.840695   Julian Zhi Jie YEE     fc2018    64.502777       68.45
# 128       66.082480          Chih-I TSAO     fc2018    59.912034       72.57
# 129       59.656715     Donovan CARRILLO     fc2018    57.620736       59.07
# 130       62.121155             He ZHANG     fc2018    57.401780       63.62
# 131       63.353375       Geon Hyeong AN     fc2018    55.280695       56.67
# 132       63.018140         Andrew DODDS     fc2018    55.138683       63.69
# 133       66.416920         Sihyeong LEE     fc2018    65.205734       62.65
# 134       66.487490    Abzal RAKIMGALIEV     fc2018    62.111482       60.77
# 135       54.180410  Leslie Man Cheuk IP     fc2018    50.207849       53.80
# 136       58.835235    Micah Kai LYNETTE     fc2018    57.537029       53.29
# 137       60.888935   Harrison J-Ye WONG     fc2018    57.972314       52.78
# 138       53.271910       Kai Xiang CHEW     fc2018    42.842268       50.92
# 139       60.377220         Mark WEBSTER     fc2018    52.946488       49.45
# 140       55.150830    Harry Hau Yin LEE     fc2018    42.763391       43.98
# 141       51.031915           Micah TANG     fc2018    43.930971       43.05
#
# [142 rows x 5 columns]

# %%
predictions2[predictions2.skater == 'Shoma UNO']
# Out:
#       Unnamed: 0    element elt_type      event  is_elt  points  prediction  \
# 240          240         4F       4j  gpcan2017       1   14.59   11.294323
# 241          241      FCSp4       sp  gpcan2017       1    4.20    4.069687
# 242          242      StSq3       st  gpcan2017       1    4.44    4.940551
# 243          243      4T+2T       4j  gpcan2017       1   13.76   10.970014
# 244          244         3A       3j  gpcan2017       1   11.78    9.069428
# 245          245      CSSp4       sp  gpcan2017       1    3.71    4.010456
# 246          246     CCoSp4       sp  gpcan2017       1    4.64    4.061950
# 324          324        4Lo       4j  gpcan2017       1   14.14   11.108533
# 325          325        3Lo       3j  gpcan2017       1    4.60    9.120333
# 326          326         3A       3j  gpcan2017       1   10.50    9.073478
# 327          327      FCSp4       sp  gpcan2017       1    4.06    4.065934
# 328          328   FCCoSp3V       sp  gpcan2017       1    3.07    4.033356
# 329          329      StSq3       st  gpcan2017       1    4.37    4.892981
# 330          330         4F       4j  gpcan2017       1   11.30   10.874735
# 331          331        4T<       4j  gpcan2017       1    4.80   11.132756
# 332          332      4T+2T       4j  gpcan2017       1   13.47   10.799849
# 333          333  3A+1Lo+3F       3j  gpcan2017       1   17.73    9.248644
# 334          334      3S+3T       3j  gpcan2017       1   10.37    9.119676
# 335          335      ChSq1       ch  gpcan2017       1    3.20    3.344857
# 336          336     CCoSp4       sp  gpcan2017       1    4.71    4.107601
# 946          946        4F<       4j  gpfra2017       1    4.60   10.966242
# 947          947      FCSp4       sp  gpfra2017       1    4.13    4.013984
# 948          948      StSq4       st  gpfra2017       1    5.40    4.868343
# 949          949      4T+3T       4j  gpfra2017       1   17.77   11.171673
# 950          950         3A       3j  gpfra2017       1    9.21    8.949611
# 951          951      CSSp4       sp  gpfra2017       1    3.37    4.015400
# 952          952     CCoSp4       sp  gpfra2017       1    4.43    4.063171
# 1016        1016        4Lo       4j  gpfra2017       1   13.86   11.257860
# 1017        1017         3A       3j  gpfra2017       1   11.07    9.096626
# 1018        1018        3Lz       3j  gpfra2017       1    5.30    8.895689
# ...          ...        ...      ...        ...     ...     ...         ...
# 3055         475        NaN       ss  gpfra2017       0    9.29    8.862097
# 3056         476        NaN       tr  gpfra2017       0    9.04    8.500092
# 3057         477        NaN       pe  gpfra2017       0    9.07    8.838282
# 3058         478        NaN       co  gpfra2017       0    9.32    8.808894
# 3059         479        NaN       in  gpfra2017       0    9.29    8.833926
# 3105         525        NaN       ss  gpfra2017       0    9.32    8.859430
# 3106         526        NaN       tr  gpfra2017       0    9.00    8.516709
# 3107         527        NaN       pe  gpfra2017       0    8.89    8.833403
# 3108         528        NaN       co  gpfra2017       0    9.18    8.792449
# 3109         529        NaN       in  gpfra2017       0    9.21    8.834201
# 3275         695        NaN       ss    gpf1718       0    9.36    8.848339
# 3276         696        NaN       tr    gpf1718       0    9.11    8.501215
# 3277         697        NaN       pe    gpf1718       0    9.32    8.839330
# 3278         698        NaN       co    gpf1718       0    9.32    8.778429
# 3279         699        NaN       in    gpf1718       0    9.36    8.827043
# 3300         720        NaN       ss    gpf1718       0    9.36    8.871007
# 3301         721        NaN       tr    gpf1718       0    8.96    8.510176
# 3302         722        NaN       pe    gpf1718       0    9.00    8.828199
# 3303         723        NaN       co    gpf1718       0    9.18    8.776016
# 3304         724        NaN       in    gpf1718       0    9.18    8.819194
# 3630        1050        NaN       ss     fc2018       0    9.18    8.867405
# 3631        1051        NaN       tr     fc2018       0    8.89    8.514453
# 3632        1052        NaN       pe     fc2018       0    9.21    8.836566
# 3633        1053        NaN       co     fc2018       0    9.11    8.771648
# 3634        1054        NaN       in     fc2018       0    9.18    8.837507
# 3785        1205        NaN       ss     fc2018       0    9.18    8.867198
# 3786        1206        NaN       tr     fc2018       0    8.96    8.518642
# 3787        1207        NaN       pe     fc2018       0    9.25    8.807757
# 3788        1208        NaN       co     fc2018       0    9.18    8.788854
# 3789        1209        NaN       in     fc2018       0    9.32    8.852920
#
#                   segment     skater  skater_code
# 240   gpcan2017 men_short  Shoma UNO          253
# 241   gpcan2017 men_short  Shoma UNO          253
# 242   gpcan2017 men_short  Shoma UNO          253
# 243   gpcan2017 men_short  Shoma UNO          253
# 244   gpcan2017 men_short  Shoma UNO          253
# 245   gpcan2017 men_short  Shoma UNO          253
# 246   gpcan2017 men_short  Shoma UNO          253
# 324    gpcan2017 men_free  Shoma UNO          253
# 325    gpcan2017 men_free  Shoma UNO          253
# 326    gpcan2017 men_free  Shoma UNO          253
# 327    gpcan2017 men_free  Shoma UNO          253
# 328    gpcan2017 men_free  Shoma UNO          253
# 329    gpcan2017 men_free  Shoma UNO          253
# 330    gpcan2017 men_free  Shoma UNO          253
# 331    gpcan2017 men_free  Shoma UNO          253
# 332    gpcan2017 men_free  Shoma UNO          253
# 333    gpcan2017 men_free  Shoma UNO          253
# 334    gpcan2017 men_free  Shoma UNO          253
# 335    gpcan2017 men_free  Shoma UNO          253
# 336    gpcan2017 men_free  Shoma UNO          253
# 946   gpfra2017 men_short  Shoma UNO          253
# 947   gpfra2017 men_short  Shoma UNO          253
# 948   gpfra2017 men_short  Shoma UNO          253
# 949   gpfra2017 men_short  Shoma UNO          253
# 950   gpfra2017 men_short  Shoma UNO          253
# 951   gpfra2017 men_short  Shoma UNO          253
# 952   gpfra2017 men_short  Shoma UNO          253
# 1016   gpfra2017 men_free  Shoma UNO          253
# 1017   gpfra2017 men_free  Shoma UNO          253
# 1018   gpfra2017 men_free  Shoma UNO          253
# ...                   ...        ...          ...
# 3055  gpfra2017 men_short  Shoma UNO          253
# 3056  gpfra2017 men_short  Shoma UNO          253
# 3057  gpfra2017 men_short  Shoma UNO          253
# 3058  gpfra2017 men_short  Shoma UNO          253
# 3059  gpfra2017 men_short  Shoma UNO          253
# 3105   gpfra2017 men_free  Shoma UNO          253
# 3106   gpfra2017 men_free  Shoma UNO          253
# 3107   gpfra2017 men_free  Shoma UNO          253
# 3108   gpfra2017 men_free  Shoma UNO          253
# 3109   gpfra2017 men_free  Shoma UNO          253
# 3275    gpf1718 men_short  Shoma UNO          253
# 3276    gpf1718 men_short  Shoma UNO          253
# 3277    gpf1718 men_short  Shoma UNO          253
# 3278    gpf1718 men_short  Shoma UNO          253
# 3279    gpf1718 men_short  Shoma UNO          253
# 3300     gpf1718 men_free  Shoma UNO          253
# 3301     gpf1718 men_free  Shoma UNO          253
# 3302     gpf1718 men_free  Shoma UNO          253
# 3303     gpf1718 men_free  Shoma UNO          253
# 3304     gpf1718 men_free  Shoma UNO          253
# 3630     fc2018 men_short  Shoma UNO          253
# 3631     fc2018 men_short  Shoma UNO          253
# 3632     fc2018 men_short  Shoma UNO          253
# 3633     fc2018 men_short  Shoma UNO          253
# 3634     fc2018 men_short  Shoma UNO          253
# 3785      fc2018 men_free  Shoma UNO          253
# 3786      fc2018 men_free  Shoma UNO          253
# 3787      fc2018 men_free  Shoma UNO          253
# 3788      fc2018 men_free  Shoma UNO          253
# 3789      fc2018 men_free  Shoma UNO          253
#
# [120 rows x 10 columns]
