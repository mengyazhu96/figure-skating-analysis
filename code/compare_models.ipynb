# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %%
with open('season2018.pickle') as f:
    season2018 = pickle.load(f)

# %%
elements_pred = pd.read_csv('fits/men_multi_elts_1.csv')
components_pred = pd.read_csv('fits/men_multi_comp_1.csv')

# %%
len(components_pred[components_pred.points > components_pred.partial_pool_predictions])
# Out:
# 1226

# %%
# 2018 data
men = pd.read_csv('pd_data/results18_men.csv')
ladies = pd.read_csv('pd_data/results18_ladies.csv')
pairs = pd.read_csv('pd_data/results18_pairs.csv')
dance = pd.read_csv('pd_data/results18_dance.csv')

# %%
with open('season2018.pickle') as f:
    season18 = pickle.load(f)
season18.load_scores()

# %%
history = pd.read_csv('pd_data/results_nowd_nofra15_men.csv')

# %%
def get_comparison(estimate_type):
    comparison = []
    for event in season2018.events:
        event_name = event.name
        elts = elements_pred[elements_pred.event == event_name].groupby('skater')[estimate_type].sum()
        comp_short = components_pred[components_pred.segment == event_name + ' men_short'].groupby('skater')[estimate_type + 's'].sum()
        comp_free = 2 * components_pred[components_pred.segment == event_name + ' men_free'].groupby('skater')[estimate_type + 's'].sum()
        predictions = {}
        outcomes = {}
        total_score = elts + comp_short
        for skater in total_score.index:
            predictions[skater] = total_score.ix[skater]
            if skater in comp_free.index:
                predictions[skater] += comp_free.ix[skater]
        for index, row in men[men.Event == event_name][['Name', 'Points']].iterrows():
            outcomes[row.Name] = row.Points
        comparison.append((predictions, outcomes))
    return comparison

# %%
def get_ranks(result_dict):
    ranks = {}
    for (i, (skater, _)) in enumerate(sorted(result_dict.iteritems(), key=lambda (k,v): -1 * v)):
        ranks[skater] = i+1
    return ranks

# %%
def calculate_loss(comparison):
    score_difference = 0.
    rank_mistake = 0
    rank_miss = {}
    for i, (predictions, outcomes) in enumerate(comparison):
        for skater in predictions:
            score_difference += (predictions[skater] - outcomes[skater])**2
            if pd.isnull(score_difference):
                print i, skater
        predicted_ranks = get_ranks(predictions)
        actual_ranks = get_ranks(outcomes)
        for skater in predictions:
            diff = abs(predicted_ranks[skater] - actual_ranks[skater])
            if diff:
                if skater not in rank_miss:
                    rank_miss[skater] = []
                rank_miss[skater].append((predicted_ranks[skater], actual_ranks[skater]))
                rank_mistake += diff
    return score_difference, rank_mistake, rank_miss

# %%
score_differences = {}
rank_mistakes = {}
rank_misses = {}
for estimate_type in ('pooled_prediction', 'unpooled_prediction', 'partial_pool_prediction'):
    comparison = get_comparison(estimate_type)
    score_difference, rank_mistake, rank_miss = calculate_loss(comparison)
    score_differences[estimate_type] = score_difference
    rank_mistakes[estimate_type] = rank_mistake
    rank_misses[estimate_type] = rank_miss

# %%
rank_mistakes, score_differences
# Out:
# ({'partial_pool_prediction': 302,
#   'pooled_prediction': 376,
#   'unpooled_prediction': 380},
#  {'partial_pool_prediction': 91053.292305282477,
#   'pooled_prediction': 204946.19175774002,
#   'unpooled_prediction': 140457656.8769297})

# %%
with open('fits/men_reputation_start_pred.csv') as f:
    short_pred, free_pred = pickle.load(f)

# %%
men.Event.unique()
# Out:
# array(['gprus2017', 'gpcan2017', 'gpchn2017', 'gpjpn2017', 'gpfra2017',
#        'gpusa2017', 'gpf1718', 'ec2018', 'fc2018'], dtype=object)

# %%
individual_bests_short = {skater: np.max(map(float, history[history.Name == skater]['Short Score']))
                          for skater in history.Name.get_values()}
len(individual_bests_short)
# Out:
# 300

# %%
have_frees = history[history['Free Rank'] != 'DNQ']
have_frees = have_frees[have_frees['Free Rank'] != 'WD']
individual_bests_free = {skater: np.max(map(float, have_frees[have_frees.Name == skater]['Free Score']))
                         for skater in have_frees.Name.get_values()}
len(individual_bests_free)
# Out:
# 238

# %%
med_short = np.median(individual_bests_short.values())
med_free = np.median(individual_bests_free.values())
med_short, med_free
# Out:
# (61.090000000000003, 124.88)

# %%
men['Short Best'] = men.apply(lambda row: med_short if row.Name not in individual_bests_short else individual_bests_short[row.Name], axis=1)
men['Free Best'] = men.apply(lambda row: med_free if row.Name not in individual_bests_free else individual_bests_free[row.Name], axis=1)

# %%
def predict_short(row):
    prediction = 20.8236
    best = med_short
    if row.Name in individual_bests_short:
        best = individual_bests_short[row.Name]
    prediction += 0.6155 * best
    return prediction + 12.3222 * float(row['Short Start']) / row['Num Short Scorecards']

def predict_free(row):
    if pd.isnull(row['Free Start']):
        return 0.
    prediction = 72.3915 
    best = med_free
    if row.Name in individual_bests_free:
        best = individual_bests_free[row.Name]
    prediction += 0.3983 * best
    return prediction + 35.2871 * float(row['Free Start']) / row['Num Free Scorecards']

# %%
men['pred_ols_short'] = men.apply(predict_short, axis=1)

# %%
men['pred_ols_free'] = men.apply(predict_free, axis=1)

# %%
ols_comparison = []
for event in season2018.events:
    competition = men[men.Event == event.name]
    predictions = {}
    outcomes = {}
    for index, row in competition.iterrows():
        predictions[row.Name] = row.pred_ols_short + row.pred_ols_free
    for index, row in competition.iterrows():
        outcomes[row.Name] = row.Points
    ols_comparison.append((predictions, outcomes))

# %%
score_difference_ols, rank_mistake_ols, rank_misses_ols = calculate_loss(ols_comparison)
score_differences['ols'] = score_difference_ols
rank_misses['ols'] = rank_misses_ols
rank_mistakes['ols'] = rank_mistake_ols

# %%
score_differences
# Out:
# {'ols': 50237.52214114873,
#  'partial_pool_prediction': 91053.292305282477,
#  'pooled_prediction': 204946.19175774002,
#  'prediction2': 57355.614637460247,
#  'prediction2.5': 44330.506868762561,
#  'unpooled_prediction': 140457656.8769297}

# %%
rank_mistakes
# Out:
# {'ols': 308,
#  'partial_pool_prediction': 302,
#  'pooled_prediction': 376,
#  'prediction2': 316,
#  'prediction2.5': 330,
#  'unpooled_prediction': 380}

# %%
def get_comparison_combined(df):
    comparison = []
    comparison_programs = []
    for event in season2018.events:
        # Predictions for this event.
        predictions = {}; outcomes = {}
        short_pred = {}; short_outcome = {}
        free_pred = {}; free_outcome = {}
        
        event_name = event.name
        short = df[df.segment == event_name + ' men_short']
        free = df[df.segment == event_name + ' men_free']
        
        # Predict elements and components
        short_elts = short[short.is_elt == 1].groupby('skater').prediction.sum()
        free_elts = free[free.is_elt == 1].groupby('skater').prediction.sum()
        comp_short = short[short.is_elt == 0].groupby('skater').prediction.sum()
        comp_free = 2 * free[free.is_elt == 0].groupby('skater').prediction.sum()

        # Predict total scores.
        short_score = short_elts + comp_short
        free_score = free_elts + comp_free
        total_score = short_score + free_score
        for skater in total_score.index:
            predictions[skater] = short_score.ix[skater]
            short_pred[skater] = short_score.ix[skater]
            if skater in free_score.index:
                predictions[skater] += free_score.ix[skater]
                free_pred[skater] = free_score.ix[skater]
        for index, row in men[men.Event == event_name][['Name', 'Points', 'Short Score', 'Free Score']].iterrows():
            outcomes[row.Name] = row.Points
            short_outcome[row.Name] = row['Short Score']
            if not pd.isnull(row['Free Score']):
                free_outcome[row.Name] = row['Free Score']
        comparison.append((predictions, outcomes))
        comparison_programs.append((short_pred, short_outcome, free_pred, free_outcome))
    return comparison, comparison_programs

# %%
predictions2 = pd.read_csv('fits/men_predictions2.csv')
score_differences['prediction2'], rank_mistakes['prediction2'], rank_misses['prediction2'] = calculate_loss(get_comparison_combined(predictions2)[0])

# %%
predictions2_5 = pd.read_csv('fits/men_predictions2.5.csv')
score_differences['prediction2.5'], rank_mistakes['prediction2.5'], rank_misses['prediction2.5'] = calculate_loss(get_comparison_combined(predictions2_5)[0])

# %%
score_differences
# Out:
# {'ols': 50237.52214114873,
#  'partial_pool_prediction': 91053.292305282477,
#  'pooled_prediction': 204946.19175774002,
#  'prediction2': 57355.614637460247,
#  'prediction2.5': 44330.506868762561,
#  'unpooled_prediction': 140457656.8769297}

# %%
rank_mistakes
# Out:
# {'ols': 308,
#  'partial_pool_prediction': 302,
#  'pooled_prediction': 376,
#  'prediction2': 316,
#  'prediction2.5': 330,
#  'unpooled_prediction': 380}

# %%
comps = predictions2_5[predictions2_5.is_elt == 0]
len(comps[comps.points > comps.prediction]), len(comps)
# Out:
# (467, 1320)

# %%
comps = predictions2[predictions2.is_elt == 0]
len(comps[comps.points > comps.prediction]), len(comps)
# Out:
# (981, 1320)

# %%
fancy_short_pred = {men.Event.unique()[i]: (get_comparison_combined(predictions2)[1][i][0], get_comparison_combined(predictions2)[1][i][1]) for i in xrange(9)}

# %%
compare = men[['pred_ols_short', 'Name', 'Event']].copy()

# %%
compare['pred2_short'] = compare.apply(lambda row: fancy_short_pred[row.Event][0][row.Name], axis=1)

# %%
compare['real_short'] = compare.apply(lambda row: fancy_short_pred[row.Event][1][row.Name], axis=1)

# %%
sum(map(lambda x: x * x, compare['pred_ols_short'] - compare['pred2_short']))
# Out:
# 5694.2237378707268

# %%
compare
# Out:
#      pred_ols_short                 Name      Event  pred2_short  real_short
# 0         94.562460          Nathan CHEN  gprus2017    91.440426      100.54
# 1        101.435525         Yuzuru HANYU  gprus2017    94.748954       94.85
# 2         89.532790      Mikhail KOLYADA  gprus2017    83.997503       85.79
# 3         77.609575             Misha GE  gprus2017    74.459113       85.02
# 4         70.178475  Moris KVITELASHVILI  gprus2017    75.456446       80.67
# 5         66.639295         Dmitri ALIEV  gprus2017    62.773720       88.77
# 6         73.937110           Nam NGUYEN  gprus2017    78.579097       80.74
# 7         78.316365     Deniss VASILJEVS  gprus2017    74.894249       82.44
# 8         83.983105            Denis TEN  gprus2017    80.448934       69.00
# 9         59.451345       Andrei LAZUKIN  gprus2017    63.671315       78.54
# 10        76.391920      Grant HOCHSTEIN  gprus2017    74.054346       67.56
# 11        81.441035       Daniel SAMOHIN  gprus2017    70.449970       62.02
# 12        97.687130            Shoma UNO  gpcan2017    92.189536      103.62
# 13        88.395150          Jason BROWN  gpcan2017    85.032751       90.71
# 14        77.618780    Alexander SAMARIN  gpcan2017    77.748320       84.02
# 15        94.979965         Patrick CHAN  gpcan2017    89.157058       94.43
# 16        79.817150      Jorik HENDRICKX  gpcan2017    74.306825       82.08
# 17        81.972435       Michal BREZINA  gpcan2017    76.595447       80.34
# 18        60.478195       Nicolas NADEAU  gpcan2017    63.197457       74.23
# 19        63.168965       Keegan MESSING  gpcan2017    66.618290       82.17
# 20        62.531895         Jun Hwan CHA  gpcan2017    63.248720       68.46
# 21        69.383445           Paul FENTZ  gpcan2017    69.872366       68.48
# 22        77.112055        Brendan KERRY  gpcan2017    64.223680       63.19
# 23        81.813440        Takahito MURA  gpcan2017    78.750456       74.82
# 24        89.532790      Mikhail KOLYADA  gpchn2017    85.522807      103.13
# 25        91.805020           Boyang JIN  gpchn2017    87.886182       93.89
# 26        83.410635            Max AARON  gpchn2017    82.061960       83.11
# 27        64.585595         Vincent ZHOU  gpchn2017    65.746369       80.23
# 28        80.412170              Han YAN  gpchn2017    78.737911       82.22
# 29       100.266075     Javier FERNANDEZ  gpchn2017    87.634979       90.57
# ..              ...                  ...        ...          ...         ...
# 112       92.215760           Boyang JIN     fc2018    87.425823      100.17
# 113       97.687130            Shoma UNO     fc2018    91.870872      100.49
# 114       89.627370          Jason BROWN     fc2018    85.345342       89.78
# 115       82.276655         Keiji TANAKA     fc2018    75.689639       90.68
# 116       85.258965            Max AARON     fc2018    78.966713       84.15
# 117       81.716975             Misha GE     fc2018    73.835179       82.27
# 118       81.865120       Kevin REYNOLDS     fc2018    76.650747       74.65
# 119       69.876880         Elladj BALDE     fc2018    70.380784       75.17
# 120       79.687470           Nam NGUYEN     fc2018    76.366282       84.09
# 121       85.751790              Han YAN     fc2018    78.344182       84.74
# 122       79.061730      Grant HOCHSTEIN     fc2018    74.255629       70.80
# 123       84.688620        Takahito MURA     fc2018    71.316620       76.66
# 124       78.960385        Brendan KERRY     fc2018    69.870944       79.57
# 125       68.457515      June Hyoung LEE     fc2018    62.046100       69.93
# 126       89.117355            Denis TEN     fc2018    79.046274       75.30
# 127       71.840695   Julian Zhi Jie YEE     fc2018    64.502777       68.45
# 128       66.082480          Chih-I TSAO     fc2018    59.912034       72.57
# 129       59.656715     Donovan CARRILLO     fc2018    57.620736       59.07
# 130       62.121155             He ZHANG     fc2018    57.401780       63.62
# 131       63.353375       Geon Hyeong AN     fc2018    55.280695       56.67
# 132       63.018140         Andrew DODDS     fc2018    55.138683       63.69
# 133       66.416920         Sihyeong LEE     fc2018    65.205734       62.65
# 134       66.487490    Abzal RAKIMGALIEV     fc2018    62.111482       60.77
# 135       54.180410  Leslie Man Cheuk IP     fc2018    50.207849       53.80
# 136       58.835235    Micah Kai LYNETTE     fc2018    57.537029       53.29
# 137       60.888935   Harrison J-Ye WONG     fc2018    57.972314       52.78
# 138       53.271910       Kai Xiang CHEW     fc2018    42.842268       50.92
# 139       60.377220         Mark WEBSTER     fc2018    52.946488       49.45
# 140       55.150830    Harry Hau Yin LEE     fc2018    42.763391       43.98
# 141       51.031915           Micah TANG     fc2018    43.930971       43.05
#
# [142 rows x 5 columns]

# %%
predictions2[predictions2.skater == 'Shoma UNO']
# Out:
#       Unnamed: 0    element elt_type      event  is_elt  points  prediction  \
# 240          240         4F       4j  gpcan2017       1   14.59   11.294323
# 241          241      FCSp4       sp  gpcan2017       1    4.20    4.069687
# 242          242      StSq3       st  gpcan2017       1    4.44    4.940551
# 243          243      4T+2T       4j  gpcan2017       1   13.76   10.970014
# 244          244         3A       3j  gpcan2017       1   11.78    9.069428
# 245          245      CSSp4       sp  gpcan2017       1    3.71    4.010456
# 246          246     CCoSp4       sp  gpcan2017       1    4.64    4.061950
# 324          324        4Lo       4j  gpcan2017       1   14.14   11.108533
# 325          325        3Lo       3j  gpcan2017       1    4.60    9.120333
# 326          326         3A       3j  gpcan2017       1   10.50    9.073478
# 327          327      FCSp4       sp  gpcan2017       1    4.06    4.065934
# 328          328   FCCoSp3V       sp  gpcan2017       1    3.07    4.033356
# 329          329      StSq3       st  gpcan2017       1    4.37    4.892981
# 330          330         4F       4j  gpcan2017       1   11.30   10.874735
# 331          331        4T<       4j  gpcan2017       1    4.80   11.132756
# 332          332      4T+2T       4j  gpcan2017       1   13.47   10.799849
# 333          333  3A+1Lo+3F       3j  gpcan2017       1   17.73    9.248644
# 334          334      3S+3T       3j  gpcan2017       1   10.37    9.119676
# 335          335      ChSq1       ch  gpcan2017       1    3.20    3.344857
# 336          336     CCoSp4       sp  gpcan2017       1    4.71    4.107601
# 946          946        4F<       4j  gpfra2017       1    4.60   10.966242
# 947          947      FCSp4       sp  gpfra2017       1    4.13    4.013984
# 948          948      StSq4       st  gpfra2017       1    5.40    4.868343
# 949          949      4T+3T       4j  gpfra2017       1   17.77   11.171673
# 950          950         3A       3j  gpfra2017       1    9.21    8.949611
# 951          951      CSSp4       sp  gpfra2017       1    3.37    4.015400
# 952          952     CCoSp4       sp  gpfra2017       1    4.43    4.063171
# 1016        1016        4Lo       4j  gpfra2017       1   13.86   11.257860
# 1017        1017         3A       3j  gpfra2017       1   11.07    9.096626
# 1018        1018        3Lz       3j  gpfra2017       1    5.30    8.895689
# ...          ...        ...      ...        ...     ...     ...         ...
# 3055         475        NaN       ss  gpfra2017       0    9.29    8.862097
# 3056         476        NaN       tr  gpfra2017       0    9.04    8.500092
# 3057         477        NaN       pe  gpfra2017       0    9.07    8.838282
# 3058         478        NaN       co  gpfra2017       0    9.32    8.808894
# 3059         479        NaN       in  gpfra2017       0    9.29    8.833926
# 3105         525        NaN       ss  gpfra2017       0    9.32    8.859430
# 3106         526        NaN       tr  gpfra2017       0    9.00    8.516709
# 3107         527        NaN       pe  gpfra2017       0    8.89    8.833403
# 3108         528        NaN       co  gpfra2017       0    9.18    8.792449
# 3109         529        NaN       in  gpfra2017       0    9.21    8.834201
# 3275         695        NaN       ss    gpf1718       0    9.36    8.848339
# 3276         696        NaN       tr    gpf1718       0    9.11    8.501215
# 3277         697        NaN       pe    gpf1718       0    9.32    8.839330
# 3278         698        NaN       co    gpf1718       0    9.32    8.778429
# 3279         699        NaN       in    gpf1718       0    9.36    8.827043
# 3300         720        NaN       ss    gpf1718       0    9.36    8.871007
# 3301         721        NaN       tr    gpf1718       0    8.96    8.510176
# 3302         722        NaN       pe    gpf1718       0    9.00    8.828199
# 3303         723        NaN       co    gpf1718       0    9.18    8.776016
# 3304         724        NaN       in    gpf1718       0    9.18    8.819194
# 3630        1050        NaN       ss     fc2018       0    9.18    8.867405
# 3631        1051        NaN       tr     fc2018       0    8.89    8.514453
# 3632        1052        NaN       pe     fc2018       0    9.21    8.836566
# 3633        1053        NaN       co     fc2018       0    9.11    8.771648
# 3634        1054        NaN       in     fc2018       0    9.18    8.837507
# 3785        1205        NaN       ss     fc2018       0    9.18    8.867198
# 3786        1206        NaN       tr     fc2018       0    8.96    8.518642
# 3787        1207        NaN       pe     fc2018       0    9.25    8.807757
# 3788        1208        NaN       co     fc2018       0    9.18    8.788854
# 3789        1209        NaN       in     fc2018       0    9.32    8.852920
#
#                   segment     skater  skater_code
# 240   gpcan2017 men_short  Shoma UNO          253
# 241   gpcan2017 men_short  Shoma UNO          253
# 242   gpcan2017 men_short  Shoma UNO          253
# 243   gpcan2017 men_short  Shoma UNO          253
# 244   gpcan2017 men_short  Shoma UNO          253
# 245   gpcan2017 men_short  Shoma UNO          253
# 246   gpcan2017 men_short  Shoma UNO          253
# 324    gpcan2017 men_free  Shoma UNO          253
# 325    gpcan2017 men_free  Shoma UNO          253
# 326    gpcan2017 men_free  Shoma UNO          253
# 327    gpcan2017 men_free  Shoma UNO          253
# 328    gpcan2017 men_free  Shoma UNO          253
# 329    gpcan2017 men_free  Shoma UNO          253
# 330    gpcan2017 men_free  Shoma UNO          253
# 331    gpcan2017 men_free  Shoma UNO          253
# 332    gpcan2017 men_free  Shoma UNO          253
# 333    gpcan2017 men_free  Shoma UNO          253
# 334    gpcan2017 men_free  Shoma UNO          253
# 335    gpcan2017 men_free  Shoma UNO          253
# 336    gpcan2017 men_free  Shoma UNO          253
# 946   gpfra2017 men_short  Shoma UNO          253
# 947   gpfra2017 men_short  Shoma UNO          253
# 948   gpfra2017 men_short  Shoma UNO          253
# 949   gpfra2017 men_short  Shoma UNO          253
# 950   gpfra2017 men_short  Shoma UNO          253
# 951   gpfra2017 men_short  Shoma UNO          253
# 952   gpfra2017 men_short  Shoma UNO          253
# 1016   gpfra2017 men_free  Shoma UNO          253
# 1017   gpfra2017 men_free  Shoma UNO          253
# 1018   gpfra2017 men_free  Shoma UNO          253
# ...                   ...        ...          ...
# 3055  gpfra2017 men_short  Shoma UNO          253
# 3056  gpfra2017 men_short  Shoma UNO          253
# 3057  gpfra2017 men_short  Shoma UNO          253
# 3058  gpfra2017 men_short  Shoma UNO          253
# 3059  gpfra2017 men_short  Shoma UNO          253
# 3105   gpfra2017 men_free  Shoma UNO          253
# 3106   gpfra2017 men_free  Shoma UNO          253
# 3107   gpfra2017 men_free  Shoma UNO          253
# 3108   gpfra2017 men_free  Shoma UNO          253
# 3109   gpfra2017 men_free  Shoma UNO          253
# 3275    gpf1718 men_short  Shoma UNO          253
# 3276    gpf1718 men_short  Shoma UNO          253
# 3277    gpf1718 men_short  Shoma UNO          253
# 3278    gpf1718 men_short  Shoma UNO          253
# 3279    gpf1718 men_short  Shoma UNO          253
# 3300     gpf1718 men_free  Shoma UNO          253
# 3301     gpf1718 men_free  Shoma UNO          253
# 3302     gpf1718 men_free  Shoma UNO          253
# 3303     gpf1718 men_free  Shoma UNO          253
# 3304     gpf1718 men_free  Shoma UNO          253
# 3630     fc2018 men_short  Shoma UNO          253
# 3631     fc2018 men_short  Shoma UNO          253
# 3632     fc2018 men_short  Shoma UNO          253
# 3633     fc2018 men_short  Shoma UNO          253
# 3634     fc2018 men_short  Shoma UNO          253
# 3785      fc2018 men_free  Shoma UNO          253
# 3786      fc2018 men_free  Shoma UNO          253
# 3787      fc2018 men_free  Shoma UNO          253
# 3788      fc2018 men_free  Shoma UNO          253
# 3789      fc2018 men_free  Shoma UNO          253
#
# [120 rows x 10 columns]
