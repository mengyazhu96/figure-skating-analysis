# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import pymc3 as pm

# %%
with open('seasons.pickle') as f:
    seasons = pickle.load(f)
for year, season in seasons.iteritems():
    print year,
    season.load_scores()

with open('season2018.pickle') as f:
    season18 = pickle.load(f)
season18.load_scores()

events = {}
for season in seasons.values():
    events.update(season.event_dict)
events.update(season18.event_dict)
# Out:
# 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017

# %%
skaters = {}
for discipline in ('men', 'ladies', 'pairs', 'dance'):
    skaters[discipline] = pd.read_csv('pd_data/results_nowd_nofra15_' + discipline + '.csv')

# %%
pairs18 = []
for event in season18.events:
    discipline = event.disciplines[2]
    segment = discipline.segments[1]
    for scorecard in segment.scorecards:
        pairs18.append({
            'Event': event.name,
            'Name': scorecard.skater.name,
            'Nation': scorecard.skater.country,
            'Points': scorecard.total_score,
            'Free PCS': scorecard.pcs,
            'Free TES': scorecard.tes
        })
pairs18 = pd.DataFrame(pairs18)

# %%
pairs_comp_type = skaters['pairs']

# %%
pairs_comp_type['is_gp'] = pairs_comp_type.apply(
    lambda row: 1 if 'gpfra' in row.Event or ('gp' in row.Event and 'gpf' not in row.Event) else 0,
    axis=1)

# %%
pairs_comp_type['is_ecfc'] = pairs_comp_type.apply(
    lambda row: 1 if row.Event[:2] == 'fc' or row.Event[:2] == 'ec' else 0,
    axis=1)

# %%
pairs_comp_type['is_champ'] = pairs_comp_type.apply(
    lambda row: 1 if row.Event[:2] == 'wc' or row.Event[:3] == 'owg' or ('gpfra' not in row.Event and 'gpf' in row.Event) 
                else 0,
    axis=1
)

# %%
history = pairs_comp_type[pairs_comp_type.Season != 2017]
individual_bests_short = {skater: np.max(map(float, history[history.Name == skater]['Short Score']))
                          for skater in history.Name.get_values()}
have_frees = history[history['Free Rank'] != 'DNQ']
have_frees = have_frees[have_frees['Free Rank'] != 'WD']
individual_bests_free = {skater: np.max(map(float, have_frees[have_frees.Name == skater]['Free Score']))
                         for skater in have_frees.Name.get_values()}
med_short = np.median(individual_bests_short.values())
med_free = np.median(individual_bests_free.values())

# %%
individual_bests = {skater: np.max(map(float, history[history.Name == skater].Points))
                    for skater in history.Name.get_values()}
med_points = np.median(individual_bests.values())
med_points
# Out:
# 145.33000000000001

# %%
data2017 = pairs_comp_type[pairs_comp_type.Season == 2017]
data2017['best_points'] = data2017.apply(
    lambda row: individual_bests.get(row.Name, med_points),
    axis=1
)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2017 = data2017[data2017['Free Rank'] != 'DNQ']
data2017 = data2017[data2017['Free Rank'] != 'WD']

# %%
X_gp = data2017.is_gp * data2017.best_points
X_ecfc = data2017.is_ecfc * data2017.best_points
X_champ = data2017.is_champ * data2017.best_points
Y = data2017['Free PCS']

# %%
np.sqrt(history.Points.var())
# Out:
# 40.208076277696897

# %%
with pm.Model() as model:

    # Priors for unknown model parameters
    alpha = pm.Normal('alpha', mu=0, sd=20)           # intercept
#     alpha_ecfc = pm.Normal('alpha_ecfc', mu=10, sd=20)
#     alpha_champ = pm.Normal('alpha_champ', mu=20, sd=20)
    beta_gp = pm.Normal('beta_gp', mu=0.0, sd=0.1)
    beta_ecfc = pm.Normal('beta_ecfc', mu=0.1, sd=0.1)
    beta_champ = pm.Normal('beta_champ', mu=0.2, sd=0.15)
    beta = pm.Normal('beta', mu=0.1, sd=0.15)
    sigma = pm.HalfNormal('sigma', sd=5)              # score variance
    
    # Expected value of outcome
    mu = (alpha + 
          beta_gp * X_gp + beta_ecfc * X_ecfc + beta_champ * X_champ + beta * data2017.best_points)

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal('Y_obs', mu=mu, sd=sigma, observed=Y)

# %%
# fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,4))
# axes[0].scatter(X1, Y)
# axes[1].scatter(X2, Y)
# axes[0].set_ylabel('Y'); axes[0].set_xlabel('X1'); axes[1].set_xlabel

# %%
with model:
    # draw 500 posterior samples
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 1000/1000 [00:09<00:00, 100.32it/s]

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127bbd210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127bdd110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127ac57d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127b1c050>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127d4f410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127db8290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127e24dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127e41e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127f26210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127fab8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12801f110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1280a4210>]], dtype=object)

# %%
pm.summary(trace)
# Out:
# alpha:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   21.211           3.343            0.184            [14.502, 27.354]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   14.774         19.096         21.134         23.322         27.771
#
#
# beta_gp:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.085            0.052            0.004            [-0.015, 0.178]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.023         0.049          0.085          0.125          0.178
#
#
# beta_ecfc:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.080            0.052            0.004            [-0.010, 0.185]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.026         0.043          0.083          0.119          0.177
#
#
# beta_champ:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.098            0.053            0.004            [0.008, 0.204]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.010         0.059          0.101          0.139          0.192
#
#
# beta:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.131            0.055            0.004            [0.024, 0.229]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.030          0.091          0.134          0.170          0.243
#
#
# sigma:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   5.937            0.482            0.028            [4.992, 6.896]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   5.070          5.608          5.913          6.249          7.094

# %%
model.alpha +
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-ab2bd7a5b3fd> in <module>()
# ----> 1 model.mu
#
# AttributeError: 'Model' object has no attribute 'mu'

# %%
ppc = pm.sample_ppc(trace, samples=100, model=model, size=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-8c9117642b6a> in <module>()
# ----> 1 ppc = pm.sample_ppc(trace, samples=100, model=model, size=100)
#
# /anaconda/lib/python2.7/site-packages/pymc3/sampling.pyc in sample_ppc(trace, samples, model, vars, size, random_seed, progressbar)
#     570             for var in vars:
#     571                 ppc[var.name].append(var.distribution.random(point=param,
# --> 572                                                              size=size))
#     573
#     574     except KeyboardInterrupt:
#
# /anaconda/lib/python2.7/site-packages/pymc3/distributions/continuous.pyc in random(self, point, size, repeat)
#     291         return generate_samples(stats.norm.rvs, loc=mu, scale=tau**-0.5,
#     292                                 dist_shape=self.shape,
# --> 293                                 size=size)
#     294
#     295     def logp(self, value):
#
# /anaconda/lib/python2.7/site-packages/pymc3/distributions/distribution.pyc in generate_samples(generator, *args, **kwargs)
#     413                                         prefix_shape,
#     414                                         *args, **kwargs)
# --> 415     return reshape_sampled(samples, size, dist_shape)
#
# /anaconda/lib/python2.7/site-packages/pymc3/distributions/distribution.pyc in reshape_sampled(sampled, size, dist_shape)
#     329
#     330     if np.size(sampled) == 1 or repeat_shape or dist_shape:
# --> 331         return np.reshape(sampled, repeat_shape + dist_shape)
#     332     else:
#     333         return sampled
#
# /anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in reshape(a, newshape, order)
#     222     except AttributeError:
#     223         return _wrapit(a, 'reshape', newshape, order=order)
# --> 224     return reshape(newshape, order=order)
#     225
#     226
#
# ValueError: total size of new array must be unchanged

# %%
import seaborn as sns
ax = plt.subplot()
sns.distplot(pairs18['Free PCS'], kde=False, ax=ax)
ax.axvline(data.mean())
ax.set(title='Posterior predictive of the mean', xlabel='mean(x)', ylabel='Frequency');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-d97fb171a79f> in <module>()
#       2 ax = plt.subplot()
#       3 sns.distplot(pairs18['Free PCS'], kde=False, ax=ax)
# ----> 4 ax.axvline(data.mean())
#       5 ax.set(title='Posterior predictive of the mean', xlabel='mean(x)', ylabel='Frequency');
#
# NameError: name 'data' is not defined

# %%
pm.SkewNormal()

# %%
pairs18['Free PCS'].hist()

# %%
pairs18['Free TES'].hist()

# %%
pairs18['Points'].hist()

# %%
history['Free PCS'].hist()

# %%
pairs18.Points.hist()

# %%
history.Points.hist()
